# %%
import pandas as pd

# %%
# Load all CSV files into dataframes

df_utilities = pd.read_csv('./datafiles/utilities.csv', low_memory=False)
df_suppliers = pd.read_csv('./datafiles/suppliers.csv', low_memory=False)
df_plans = pd.read_csv('./datafiles/plans.csv', low_memory=False)
df_rates = pd.read_csv('./datafiles/rates.csv', low_memory=False)
df_amounts = pd.read_csv('./datafiles/amounts.csv', low_memory=False)
df_monthly_charges = pd.read_csv('./datafiles/monthly_charges.csv', low_memory=False)
df_usage_credits = pd.read_csv('./datafiles/usage_credits.csv', low_memory=False)
df_early_term_fees = pd.read_csv('./datafiles/early_term_fees.csv', low_memory=False)
df_benefits = pd.read_csv('./datafiles/benefits.csv', low_memory=False)

# %%
df_utilities.rename(columns={'id': 'utility_id', 'name': 'utility_name'}, inplace=True)
df_suppliers.rename(columns={'id': 'supplier_id', 'name': 'supplier_name'}, inplace=True)
df_plans.rename(columns={'id': 'plan_id'}, inplace=True)
df_rates.rename(columns={'id': 'rate_id'}, inplace=True)
df_amounts.rename(columns={'id': 'amount_id'}, inplace=True)
df_monthly_charges.rename(columns={'id': 'monthly_charge_id'}, inplace=True)
df_usage_credits.rename(columns={'id': 'usage_credit_id'}, inplace=True)
df_early_term_fees.rename(columns={'id': 'early_term_fee_id'}, inplace=True)
df_benefits.rename(columns={'id': 'benefit_id'}, inplace=True)

# %%
df_plans_missing = df_plans [df_plans ['created_at'].isnull()]
df_plans_missing
# Out:
#        plan_id created_at state rate_unit  contact_number is_variable  \
# 22278    22279        NaN    pa       kWh  1-888-313-9086       False
# 26694    26695        NaN    pa       kWh  1-888-313-9086       False
# 29202    29203        NaN    pa       kWh             NaN        True
# 29203    29204        NaN    pa       kWh             NaN         NaN
# 29204    29205        NaN    pa       kWh             NaN         NaN
# 29205    29206        NaN    pa       kWh             NaN         NaN
#
#       rate_type is_green description  term  ...  green_details  \
# 22278     fixed    False         NaN   6.0  ...  25% renewable
# 26694     fixed    False         NaN   6.0  ...  25% renewable
# 29202  variable    False         NaN   NaN  ...            NaN
# 29203     fixed    False         NaN   NaN  ...            NaN
# 29204     fixed    False         NaN   NaN  ...            NaN
# 29205     fixed     True         NaN  12.0  ...           wind
#
#       green_percentage  start_date service_type term_end_date plan_end_date  \
# 22278             25.0         NaN          NaN           NaN           NaN
# 26694             25.0         NaN  Residential           NaN           NaN
# 29202              NaN         NaN          NaN           NaN           NaN
# 29203              NaN         NaN          NaN           NaN           NaN
# 29204              NaN         NaN          NaN           NaN           NaN
# 29205            100.0         NaN          NaN           NaN           NaN
#
#       sq_ft_2600  sq_ft_800                    plan_type supplier_id
# 22278        NaN        NaN  Regular Residential Service          50
# 26694        NaN        NaN                          NaN          50
# 29202        NaN        NaN  Regular Residential Service          85
# 29203        NaN        NaN  Regular Residential Service          85
# 29204        NaN        NaN  Regular Residential Service          85
# 29205        NaN        NaN  Regular Residential Service          85
#
# [6 rows x 21 columns]

# %%
df_rates_missing = df_rates [df_rates ['createdAt'].isnull()]
df_rates_missing
# Out:
#        rate_id     rate_type  min_value max_value  utility_id  plan_id  \
# 16484    16485  default rate          0       NaN         8.0      NaN
# 20543    20544  default rate          0       NaN         8.0      NaN
# 21102    21103  default rate          0       NaN         8.0      NaN
# 21599    21600  default rate          0       NaN         8.0      NaN
# 22140    22141  default rate          0       NaN         8.0      NaN
# 22555    22556  default rate          0       NaN         8.0      NaN
# 23080    23081  default rate          0       NaN         8.0      NaN
# 23557    23558  default rate          0       NaN         8.0      NaN
# 24039    24040  default rate          0       NaN         8.0      NaN
# 24599    24600  default rate          0       NaN         8.0      NaN
# 25126    25127           NaN          0       NaN         NaN  22279.0
# 25167    25168  default rate          0       NaN         8.0      NaN
# 29544    29545           NaN          0       NaN         NaN  26695.0
# 32032    32033           NaN          0       NaN         NaN  29203.0
# 32033    32034           NaN          0       NaN         NaN  29204.0
# 32034    32035           NaN          0       NaN         NaN  29205.0
# 32035    32036           NaN          0       NaN         NaN  29206.0
#
#       createdAt
# 16484       NaN
# 20543       NaN
# 21102       NaN
# 21599       NaN
# 22140       NaN
# 22555       NaN
# 23080       NaN
# 23557       NaN
# 24039       NaN
# 24599       NaN
# 25126       NaN
# 25167       NaN
# 29544       NaN
# 32032       NaN
# 32033       NaN
# 32034       NaN
# 32035       NaN

# %%
# drop plans with missing created_at column
df_plans = df_plans.dropna(subset=['created_at'])
df_rates = df_rates.dropna(subset=['createdAt'])

# %%
# Add 'rate_source' column to df_rates
df_rates['rate_source'] = df_rates.apply(
    lambda x: 'utility_rate' if pd.notnull(x['utility_id']) else 'plan_rate', axis=1
)

# %%
# Split df_rates into utility rates and plan rates
df_utility_rates = df_rates[df_rates['rate_source'] == 'utility_rate']
df_plan_rates = df_rates[df_rates['rate_source'] == 'plan_rate']

# %%
# Merge df_plan_rates with df_plans
df_plan_rates = df_plan_rates.merge(df_plans, how='left', on='plan_id', suffixes=('', '_plan'))

# %%
# merge df_plan_rates with df_suppliers on 'supplier_id'
df_plan_rates = df_plan_rates.merge(df_suppliers[['supplier_id', 'supplier_name', 'utility_id']], how='left', on='supplier_id')

# %%
df_plan_rates.rename(columns={
    'utility_id_y': 'utility_id',
}, inplace=True)

# %%
# add utility name and utility names
df_plan_rates = df_plan_rates.merge(df_utilities[['utility_id', 'utility_name']], how='left', on='utility_id')

# %%
missing_plan_dates_df= df_plan_rates [df_plan_rates ['createdAt'].isnull()]

# Display the filtered DataFrame
print("Plans with missing 'plan_rate_created_at':")
missing_plan_dates_df
# Out:
# Plans with missing 'plan_rate_created_at':
# Empty DataFrame
# Columns: [rate_id, rate_type, min_value, max_value, utility_id_x, plan_id, createdAt, rate_source, created_at, state, rate_unit, contact_number, is_variable, rate_type_plan, is_green, description, term, website_url, green_details, green_percentage, start_date, service_type, term_end_date, plan_end_date, sq_ft_2600, sq_ft_800, plan_type, supplier_id, supplier_name, utility_id, utility_name]
# Index: []
#
# [0 rows x 31 columns]

# %%
# drop rows that have a missing

# %%
# get amounts associated with plan rates
df_amounts_plan = df_amounts[df_amounts['rate_id'].isin(df_plan_rates['rate_id'])]

# %%
# Merge amounts with plan rates
df_plan_rates = df_plan_rates.merge(df_amounts_plan, how='left', on='rate_id')

# %%
df_plan_rates.rename(columns={'value': 'plan_rate_amount'}, inplace=True)

# %%
df_plan_rates
# Out:
#         rate_id rate_type  min_value max_value  utility_id_x   plan_id  \
# 0             2       NaN          0       NaN           NaN       1.0
# 1             3       NaN          0       NaN           NaN       2.0
# 2             4       NaN          0      1200           NaN       3.0
# 3             5       NaN       1201       NaN           NaN       3.0
# 4             6       NaN          0      1200           NaN       4.0
# ...         ...       ...        ...       ...           ...       ...
# 656488   659375       NaN          0       NaN           NaN  656737.0
# 656489   659376       NaN          0       NaN           NaN  656738.0
# 656490   659377       NaN          0       NaN           NaN  656739.0
# 656491   659378       NaN          0       NaN           NaN  656740.0
# 656492   659379       NaN          0       NaN           NaN  656741.0
#
#          createdAt rate_source  created_at state  ... supplier_id  \
# 0       1999-07-30   plan_rate  1999-07-30    pa  ...           1
# 1       1999-07-30   plan_rate  1999-07-30    pa  ...           2
# 2       1999-07-30   plan_rate  1999-07-30    pa  ...           2
# 3       1999-07-30   plan_rate  1999-07-30    pa  ...           2
# 4       1999-07-30   plan_rate  1999-07-30    pa  ...           2
# ...            ...         ...         ...   ...  ...         ...
# 656488  2021-07-21   plan_rate  2021-07-21    pa  ...          58
# 656489  2021-07-21   plan_rate  2021-07-21    pa  ...          58
# 656490  2021-07-21   plan_rate  2021-07-21    pa  ...          94
# 656491  2021-07-21   plan_rate  2021-07-21    pa  ...          94
# 656492  2021-07-21   plan_rate  2021-07-21    pa  ...         139
#
#                 supplier_name utility_id     utility_name  amount_id  \
# 0                 FirstEnergy          1  Allegheny Power        2.0
# 1       Green Mountain Energy          1  Allegheny Power        4.0
# 2       Green Mountain Energy          1  Allegheny Power        6.0
# 3       Green Mountain Energy          1  Allegheny Power        7.0
# 4       Green Mountain Energy          1  Allegheny Power        9.0
# ...                       ...        ...              ...        ...
# 656488           Ambit Energy          3      PECO Energy  1773845.0
# 656489           Ambit Energy          3      PECO Energy  1773848.0
# 656490         Energy Rewards          4          Penelec  1773851.0
# 656491         Energy Rewards          4          Penelec  1773854.0
# 656492       Clean Sky Energy         10  West Penn Power  1773857.0
#
#        from_value  to_value plan_rate_amount usage_credit_id  \
# 0             NaN       NaN             4.40             NaN
# 1             NaN       NaN             4.04             NaN
# 2             NaN       NaN             5.06             NaN
# 3             NaN       NaN             4.23             NaN
# 4             NaN       NaN             5.70             NaN
# ...           ...       ...              ...             ...
# 656488        NaN       NaN             6.95             NaN
# 656489        NaN       NaN             6.95             NaN
# 656490        NaN       NaN             8.69             NaN
# 656491        NaN       NaN             8.59             NaN
# 656492        NaN       NaN             6.99             NaN
#
#         monthly_charge_id
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 656488                NaN
# 656489                NaN
# 656490                NaN
# 656491                NaN
# 656492                NaN
#
# [656493 rows x 37 columns]

# %%
df_plan_rates.columns
# Out:
# Index(['rate_id', 'rate_type', 'min_value', 'max_value', 'utility_id_x',
#        'plan_id', 'createdAt', 'rate_source', 'created_at', 'state',
#        'rate_unit', 'contact_number', 'is_variable', 'rate_type_plan',
#        'is_green', 'description', 'term', 'website_url', 'green_details',
#        'green_percentage', 'start_date', 'service_type', 'term_end_date',
#        'plan_end_date', 'sq_ft_2600', 'sq_ft_800', 'plan_type', 'supplier_id',
#        'supplier_name', 'utility_id', 'utility_name', 'amount_id',
#        'from_value', 'to_value', 'plan_rate_amount', 'usage_credit_id',
#        'monthly_charge_id'],
#       dtype='object')

# %%
# Specify the columns to drop as a list
columns_to_drop = ['rate_id', 'rate_type', 'utility_id_x', 'rate_source',
        'amount_id', 'usage_credit_id','created_at','monthly_charge_id']

# %%
# Drop the columns and update the DataFrame in place
df_plan_rates.drop(columns=columns_to_drop, inplace=True)

# %%
df_plan_rates
# Out:
#         min_value max_value   plan_id   createdAt state rate_unit  \
# 0               0       NaN       1.0  1999-07-30    pa       kWh
# 1               0       NaN       2.0  1999-07-30    pa       kWh
# 2               0      1200       3.0  1999-07-30    pa       kWh
# 3            1201       NaN       3.0  1999-07-30    pa       kWh
# 4               0      1200       4.0  1999-07-30    pa       kWh
# ...           ...       ...       ...         ...   ...       ...
# 656488          0       NaN  656737.0  2021-07-21    pa       kWh
# 656489          0       NaN  656738.0  2021-07-21    pa       kWh
# 656490          0       NaN  656739.0  2021-07-21    pa       kWh
# 656491          0       NaN  656740.0  2021-07-21    pa       kWh
# 656492          0       NaN  656741.0  2021-07-21    pa       kWh
#
#        contact_number is_variable rate_type_plan is_green  ... sq_ft_2600  \
# 0        888-254-9227        True       variable    False  ...        NaN
# 1        888-246-6730        True       variable    False  ...        NaN
# 2        888-246-6730        True       variable    False  ...        NaN
# 3        888-246-6730        True       variable    False  ...        NaN
# 4        888-246-6730        True       variable     True  ...        NaN
# ...               ...         ...            ...      ...  ...        ...
# 656488            NaN         NaN          fixed    False  ...       6.95
# 656489            NaN         NaN          fixed    False  ...       6.95
# 656490            NaN         NaN          fixed    False  ...       8.69
# 656491            NaN         NaN          fixed    False  ...       8.59
# 656492            NaN         NaN          fixed    False  ...       6.99
#
#         sq_ft_800                    plan_type supplier_id  \
# 0             NaN  Regular Residential Service           1
# 1             NaN  Regular Residential Service           2
# 2             NaN  Regular Residential Service           2
# 3             NaN  Regular Residential Service           2
# 4             NaN  Regular Residential Service           2
# ...           ...                          ...         ...
# 656488       6.95                          NaN          58
# 656489       6.95                          NaN          58
# 656490       8.69                          NaN          94
# 656491       8.59                          NaN          94
# 656492       6.99                          new         139
#
#                 supplier_name utility_id     utility_name from_value to_value  \
# 0                 FirstEnergy          1  Allegheny Power        NaN      NaN
# 1       Green Mountain Energy          1  Allegheny Power        NaN      NaN
# 2       Green Mountain Energy          1  Allegheny Power        NaN      NaN
# 3       Green Mountain Energy          1  Allegheny Power        NaN      NaN
# 4       Green Mountain Energy          1  Allegheny Power        NaN      NaN
# ...                       ...        ...              ...        ...      ...
# 656488           Ambit Energy          3      PECO Energy        NaN      NaN
# 656489           Ambit Energy          3      PECO Energy        NaN      NaN
# 656490         Energy Rewards          4          Penelec        NaN      NaN
# 656491         Energy Rewards          4          Penelec        NaN      NaN
# 656492       Clean Sky Energy         10  West Penn Power        NaN      NaN
#
#         plan_rate_amount
# 0                   4.40
# 1                   4.04
# 2                   5.06
# 3                   4.23
# 4                   5.70
# ...                  ...
# 656488              6.95
# 656489              6.95
# 656490              8.69
# 656491              8.59
# 656492              6.99
#
# [656493 rows x 29 columns]

# %%
# Rename columns to include 'plan_rate_' prefix
df_plan_rates.rename(columns={
    'min_value': 'plan_rate_min_value',
    'max_value': 'plan_rate_max_value',
    'createdAt': 'created_at',
    'from_value': 'plan_rate_from_value',
    'to_value': 'plan_rate_to_value'
}, inplace=True)

# %%
df_plan_rates.columns
# Out:
# Index(['plan_rate_min_value', 'plan_rate_max_value', 'plan_id', 'created_at',
#        'state', 'rate_unit', 'contact_number', 'is_variable', 'rate_type_plan',
#        'is_green', 'description', 'term', 'website_url', 'green_details',
#        'green_percentage', 'start_date', 'service_type', 'term_end_date',
#        'plan_end_date', 'sq_ft_2600', 'sq_ft_800', 'plan_type', 'supplier_id',
#        'supplier_name', 'utility_id', 'utility_name', 'plan_rate_from_value',
#        'plan_rate_to_value', 'plan_rate_amount'],
#       dtype='object')

# %%
# Define the columns to keep
plan_columns = [
    'utility_id',
    'utility_name',
    'supplier_id',
    'supplier_name',
    'plan_id',
    'created_at',
    'state',
    'rate_unit',
    'contact_number',
    'is_variable',
    'rate_type_plan',
    'is_green',
    'description',
    'term',
    'website_url',
    'green_details',
    'green_percentage',
    'start_date',
    'service_type',
    'term_end_date',
    'plan_end_date',
    'sq_ft_2600',
    'sq_ft_800',
    'plan_type',
    'plan_rate_min_value',
    'plan_rate_max_value',
    'plan_rate_from_value',
    'plan_rate_to_value',
    'plan_rate_amount',
]

# %%
# Select the columns
df_utility_plan_rates_amounts = df_plan_rates[plan_columns]

# %%
df_utility_plan_rates_amounts
# Out:
#         utility_id     utility_name  supplier_id          supplier_name  \
# 0                1  Allegheny Power            1            FirstEnergy
# 1                1  Allegheny Power            2  Green Mountain Energy
# 2                1  Allegheny Power            2  Green Mountain Energy
# 3                1  Allegheny Power            2  Green Mountain Energy
# 4                1  Allegheny Power            2  Green Mountain Energy
# ...            ...              ...          ...                    ...
# 656488           3      PECO Energy           58           Ambit Energy
# 656489           3      PECO Energy           58           Ambit Energy
# 656490           4          Penelec           94         Energy Rewards
# 656491           4          Penelec           94         Energy Rewards
# 656492          10  West Penn Power          139       Clean Sky Energy
#
#          plan_id  created_at state rate_unit contact_number is_variable  ...  \
# 0            1.0  1999-07-30    pa       kWh   888-254-9227        True  ...
# 1            2.0  1999-07-30    pa       kWh   888-246-6730        True  ...
# 2            3.0  1999-07-30    pa       kWh   888-246-6730        True  ...
# 3            3.0  1999-07-30    pa       kWh   888-246-6730        True  ...
# 4            4.0  1999-07-30    pa       kWh   888-246-6730        True  ...
# ...          ...         ...   ...       ...            ...         ...  ...
# 656488  656737.0  2021-07-21    pa       kWh            NaN         NaN  ...
# 656489  656738.0  2021-07-21    pa       kWh            NaN         NaN  ...
# 656490  656739.0  2021-07-21    pa       kWh            NaN         NaN  ...
# 656491  656740.0  2021-07-21    pa       kWh            NaN         NaN  ...
# 656492  656741.0  2021-07-21    pa       kWh            NaN         NaN  ...
#
#        term_end_date plan_end_date sq_ft_2600  sq_ft_800  \
# 0                NaN           NaN        NaN        NaN
# 1                NaN           NaN        NaN        NaN
# 2                NaN           NaN        NaN        NaN
# 3                NaN           NaN        NaN        NaN
# 4                NaN           NaN        NaN        NaN
# ...              ...           ...        ...        ...
# 656488           NaN           NaN       6.95       6.95
# 656489           NaN           NaN       6.95       6.95
# 656490           NaN           NaN       8.69       8.69
# 656491           NaN           NaN       8.59       8.59
# 656492           NaN           NaN       6.99       6.99
#
#                           plan_type plan_rate_min_value  plan_rate_max_value  \
# 0       Regular Residential Service                   0                  NaN
# 1       Regular Residential Service                   0                  NaN
# 2       Regular Residential Service                   0                 1200
# 3       Regular Residential Service                1201                  NaN
# 4       Regular Residential Service                   0                 1200
# ...                             ...                 ...                  ...
# 656488                          NaN                   0                  NaN
# 656489                          NaN                   0                  NaN
# 656490                          NaN                   0                  NaN
# 656491                          NaN                   0                  NaN
# 656492                          new                   0                  NaN
#
#        plan_rate_from_value plan_rate_to_value plan_rate_amount
# 0                       NaN                NaN             4.40
# 1                       NaN                NaN             4.04
# 2                       NaN                NaN             5.06
# 3                       NaN                NaN             4.23
# 4                       NaN                NaN             5.70
# ...                     ...                ...              ...
# 656488                  NaN                NaN             6.95
# 656489                  NaN                NaN             6.95
# 656490                  NaN                NaN             8.69
# 656491                  NaN                NaN             8.59
# 656492                  NaN                NaN             6.99
#
# [656493 rows x 29 columns]

# %%
# Filter amounts associated with utility rates
df_amounts_utility = df_amounts[df_amounts['rate_id'].isin(df_utility_rates['rate_id'])]

# Merge amounts with utility rates
df_utility_rates = df_utility_rates.merge(df_amounts_utility, how='left', on='rate_id')

# %%
df_utility_rates
# Out:
#       rate_id                           rate_type  min_value max_value  \
# 0           1                        default rate          0       NaN
# 1          10                        default rate          0       NaN
# 2          25  default residential heat pump rate          0       500
# 3          26  default residential heat pump rate        501       NaN
# 4          47                        default rate          0       NaN
# ...       ...                                 ...        ...       ...
# 2987   659498                        default rate          0       NaN
# 2988   659499                        default rate          0       NaN
# 2989   659500                        default rate          0       NaN
# 2990   659501                        default rate          0         -
# 2991   659502                        default rate          0         -
#
#       utility_id  plan_id   createdAt   rate_source  amount_id  from_value  \
# 0            1.0      NaN  1999-07-30  utility_rate          1         NaN
# 1            2.0      NaN  1999-07-30  utility_rate         16         NaN
# 2            3.0      NaN  1999-07-30  utility_rate         48         NaN
# 3            3.0      NaN  1999-07-30  utility_rate         49         NaN
# 4            4.0      NaN  1999-07-30  utility_rate         92         NaN
# ...          ...      ...         ...           ...        ...         ...
# 2987         3.0      NaN  2020-09-02  utility_rate    1773978         NaN
# 2988         3.0      NaN  2020-09-02  utility_rate    1773979         NaN
# 2989         3.0      NaN  2020-09-03  utility_rate    1773980         NaN
# 2990         3.0      NaN  2023-09-14  utility_rate    1773981         NaN
# 2991         3.0      NaN  2024-03-20  utility_rate    1773982         NaN
#
#       to_value  value  usage_credit_id  monthly_charge_id
# 0          NaN  3.221              NaN                NaN
# 1          NaN  4.522              NaN                NaN
# 2          NaN  5.770              NaN                NaN
# 3          NaN  6.470              NaN                NaN
# 4          NaN  4.528              NaN                NaN
# ...        ...    ...              ...                ...
# 2987       NaN  6.369              NaN                NaN
# 2988       NaN  6.405              NaN                NaN
# 2989       NaN  6.369              NaN                NaN
# 2990       NaN  8.917              NaN                NaN
# 2991       NaN  9.425              NaN                NaN
#
# [2992 rows x 14 columns]

# %%
df_utility_rates.columns
# Out:
# Index(['rate_id', 'rate_type', 'min_value', 'max_value', 'utility_id',
#        'plan_id', 'createdAt', 'rate_source', 'amount_id', 'from_value',
#        'to_value', 'value', 'usage_credit_id', 'monthly_charge_id'],
#       dtype='object')

# %%
utility_rates_columns = [
    "utility_id","rate_type","createdAt","from_value","to_value","value"
]

# Select the columns
df_utility_rates_amounts = df_utility_rates[utility_rates_columns].copy()

# %%
df_utility_rates_amounts
# Out:
#       utility_id                           rate_type   createdAt  from_value  \
# 0            1.0                        default rate  1999-07-30         NaN
# 1            2.0                        default rate  1999-07-30         NaN
# 2            3.0  default residential heat pump rate  1999-07-30         NaN
# 3            3.0  default residential heat pump rate  1999-07-30         NaN
# 4            4.0                        default rate  1999-07-30         NaN
# ...          ...                                 ...         ...         ...
# 2987         3.0                        default rate  2020-09-02         NaN
# 2988         3.0                        default rate  2020-09-02         NaN
# 2989         3.0                        default rate  2020-09-03         NaN
# 2990         3.0                        default rate  2023-09-14         NaN
# 2991         3.0                        default rate  2024-03-20         NaN
#
#       to_value  value
# 0          NaN  3.221
# 1          NaN  4.522
# 2          NaN  5.770
# 3          NaN  6.470
# 4          NaN  4.528
# ...        ...    ...
# 2987       NaN  6.369
# 2988       NaN  6.405
# 2989       NaN  6.369
# 2990       NaN  8.917
# 2991       NaN  9.425
#
# [2992 rows x 6 columns]

# %%
# Rename columns to include 'plan_rate_' prefix
df_utility_rates_amounts.rename(columns={
    'createdAt': 'created_at',
    'from_value': 'utility_rate_from_value',
    'to_value': 'utility_rate_to_value',
    'value': 'utility_rate_value',
    'rate_type': 'utility_rate_type',
}, inplace=True)

# %%
df_utility_rates_amounts
# Out:
#       utility_id                   utility_rate_type  created_at  \
# 0            1.0                        default rate  1999-07-30
# 1            2.0                        default rate  1999-07-30
# 2            3.0  default residential heat pump rate  1999-07-30
# 3            3.0  default residential heat pump rate  1999-07-30
# 4            4.0                        default rate  1999-07-30
# ...          ...                                 ...         ...
# 2987         3.0                        default rate  2020-09-02
# 2988         3.0                        default rate  2020-09-02
# 2989         3.0                        default rate  2020-09-03
# 2990         3.0                        default rate  2023-09-14
# 2991         3.0                        default rate  2024-03-20
#
#       utility_rate_from_value  utility_rate_to_value  utility_rate_value
# 0                         NaN                    NaN               3.221
# 1                         NaN                    NaN               4.522
# 2                         NaN                    NaN               5.770
# 3                         NaN                    NaN               6.470
# 4                         NaN                    NaN               4.528
# ...                       ...                    ...                 ...
# 2987                      NaN                    NaN               6.369
# 2988                      NaN                    NaN               6.405
# 2989                      NaN                    NaN               6.369
# 2990                      NaN                    NaN               8.917
# 2991                      NaN                    NaN               9.425
#
# [2992 rows x 6 columns]

# %%
# add names to utility _rates_amounts
df_utility_rates_amounts = pd.merge(df_utilities,df_utility_rates_amounts,on="utility_id")

# %%
df_utility_rates_amounts
# Out:
#       utility_id     utility_name utility_rate_type  created_at  \
# 0              1  Allegheny Power      default rate  1999-07-30
# 1              1  Allegheny Power      default rate  1999-07-30
# 2              1  Allegheny Power      default rate  1999-09-30
# 3              1  Allegheny Power      default rate  2000-03-31
# 4              1  Allegheny Power      default rate  2000-07-31
# ...          ...              ...               ...         ...
# 2987          10  West Penn Power      default rate  2019-09-01
# 2988          10  West Penn Power      default rate  2019-12-01
# 2989          10  West Penn Power      default rate  2020-04-06
# 2990          10  West Penn Power      default rate  2023-09-14
# 2991          10  West Penn Power      default rate  2023-12-07
#
#       utility_rate_from_value  utility_rate_to_value  utility_rate_value
# 0                         NaN                    NaN               3.221
# 1                         NaN                    NaN               3.221
# 2                         NaN                    NaN               3.221
# 3                         NaN                    NaN               3.243
# 4                         NaN                    NaN               3.243
# ...                       ...                    ...                 ...
# 2987                      NaN                    NaN               5.338
# 2988                      NaN                    NaN               5.760
# 2989                      NaN                    NaN               6.059
# 2990                      NaN                    NaN               9.929
# 2991                      NaN                    NaN               9.997
#
# [2992 rows x 7 columns]

# %%
# Convert 'plan_rate_created_at' to datetime
df_utility_plan_rates_amounts['created_at'] = pd.to_datetime(df_utility_plan_rates_amounts['created_at'])

# Convert 'utility_created_at' to datetime
df_utility_rates_amounts['created_at'] = pd.to_datetime(df_utility_rates_amounts['created_at'])

# %%
# Sort df_utility_rates_amounts by 'utility_id' and 'utility_created_at'
df_utility_rates_amounts_sorted = df_utility_rates_amounts.sort_values(['utility_id', 'created_at'])

# Sort df_utility_plan_rates_amounts by 'utility_id' and 'plan_rate_created_at'
df_utility_plan_rates_amounts_sorted = df_utility_plan_rates_amounts.sort_values(['utility_id', 'created_at'])

# %%
# Convert 'utility_id' to int64 in df_utility_rates_amounts
df_utility_rates_amounts_sorted['utility_id'] = df_utility_rates_amounts_sorted['utility_id'].astype('int64')

# Convert 'utility_id' to int64 in df_utility_plan_rates_amounts
df_utility_plan_rates_amounts_sorted['utility_id'] = df_utility_plan_rates_amounts_sorted['utility_id'].astype('int64')

# %%
print("Data types in df_utility_rates_amounts:")
print(df_utility_rates_amounts_sorted[['utility_id']].dtypes)

# Check data types of 'utility_id' in df_utility_plan_rates_amounts
print("\nData types in df_utility_plan_rates_amounts:")
print(df_utility_plan_rates_amounts_sorted[['utility_id']].dtypes)
# Out:
# Data types in df_utility_rates_amounts:
# utility_id    int64
# dtype: object
#
# Data types in df_utility_plan_rates_amounts:
# utility_id    int64
# dtype: object

# %%
df_utility_rates_amounts_sorted.columns
# Out:
# Index(['utility_id', 'utility_name', 'utility_rate_type', 'created_at',
#        'utility_rate_from_value', 'utility_rate_to_value',
#        'utility_rate_value'],
#       dtype='object')

# %%
df_utility_plan_rates_amounts_sorted.columns
# Out:
# Index(['utility_id', 'utility_name', 'supplier_id', 'supplier_name', 'plan_id',
#        'created_at', 'state', 'rate_unit', 'contact_number', 'is_variable',
#        'rate_type_plan', 'is_green', 'description', 'term', 'website_url',
#        'green_details', 'green_percentage', 'start_date', 'service_type',
#        'term_end_date', 'plan_end_date', 'sq_ft_2600', 'sq_ft_800',
#        'plan_type', 'plan_rate_min_value', 'plan_rate_max_value',
#        'plan_rate_from_value', 'plan_rate_to_value', 'plan_rate_amount'],
#       dtype='object')

# %%
df_utility_rates_amounts_sorted
# Out:
#       utility_id     utility_name utility_rate_type created_at  \
# 0              1  Allegheny Power      default rate 1999-07-30
# 1              1  Allegheny Power      default rate 1999-07-30
# 2              1  Allegheny Power      default rate 1999-09-30
# 6              1  Allegheny Power      default rate 2000-02-25
# 7              1  Allegheny Power      default rate 2000-02-25
# ...          ...              ...               ...        ...
# 2987          10  West Penn Power      default rate 2019-09-01
# 2988          10  West Penn Power      default rate 2019-12-01
# 2989          10  West Penn Power      default rate 2020-04-06
# 2990          10  West Penn Power      default rate 2023-09-14
# 2991          10  West Penn Power      default rate 2023-12-07
#
#       utility_rate_from_value  utility_rate_to_value  utility_rate_value
# 0                         NaN                    NaN               3.221
# 1                         NaN                    NaN               3.221
# 2                         NaN                    NaN               3.221
# 6                         NaN                    NaN               3.243
# 7                         NaN                    NaN               3.243
# ...                       ...                    ...                 ...
# 2987                      NaN                    NaN               5.338
# 2988                      NaN                    NaN               5.760
# 2989                      NaN                    NaN               6.059
# 2990                      NaN                    NaN               9.929
# 2991                      NaN                    NaN               9.997
#
# [2992 rows x 7 columns]

# %%
df_utility_plan_rates_amounts_sorted
# Out:
#         utility_id     utility_name  supplier_id          supplier_name  \
# 0                1  Allegheny Power            1            FirstEnergy
# 1                1  Allegheny Power            2  Green Mountain Energy
# 2                1  Allegheny Power            2  Green Mountain Energy
# 3                1  Allegheny Power            2  Green Mountain Energy
# 4                1  Allegheny Power            2  Green Mountain Energy
# ...            ...              ...          ...                    ...
# 656478          10  West Penn Power          115        Tomorrow Energy
# 656479          10  West Penn Power           96     Town Square Energy
# 656480          10  West Penn Power           96     Town Square Energy
# 656481          10  West Penn Power           96     Town Square Energy
# 656492          10  West Penn Power          139       Clean Sky Energy
#
#          plan_id created_at state rate_unit contact_number is_variable  ...  \
# 0            1.0 1999-07-30    pa       kWh   888-254-9227        True  ...
# 1            2.0 1999-07-30    pa       kWh   888-246-6730        True  ...
# 2            3.0 1999-07-30    pa       kWh   888-246-6730        True  ...
# 3            3.0 1999-07-30    pa       kWh   888-246-6730        True  ...
# 4            4.0 1999-07-30    pa       kWh   888-246-6730        True  ...
# ...          ...        ...   ...       ...            ...         ...  ...
# 656478  656727.0 2021-07-21    pa       kWh            NaN         NaN  ...
# 656479  656728.0 2021-07-21    pa       kWh            NaN         NaN  ...
# 656480  656729.0 2021-07-21    pa       kWh            NaN         NaN  ...
# 656481  656730.0 2021-07-21    pa       kWh            NaN         NaN  ...
# 656492  656741.0 2021-07-21    pa       kWh            NaN         NaN  ...
#
#        term_end_date plan_end_date sq_ft_2600  sq_ft_800  \
# 0                NaN           NaN        NaN        NaN
# 1                NaN           NaN        NaN        NaN
# 2                NaN           NaN        NaN        NaN
# 3                NaN           NaN        NaN        NaN
# 4                NaN           NaN        NaN        NaN
# ...              ...           ...        ...        ...
# 656478           NaN           NaN       7.67       7.67
# 656479           NaN           NaN       6.04       6.04
# 656480           NaN           NaN       7.97       7.97
# 656481           NaN           NaN       7.97       7.97
# 656492           NaN           NaN       6.99       6.99
#
#                           plan_type plan_rate_min_value  plan_rate_max_value  \
# 0       Regular Residential Service                   0                  NaN
# 1       Regular Residential Service                   0                  NaN
# 2       Regular Residential Service                   0                 1200
# 3       Regular Residential Service                1201                  NaN
# 4       Regular Residential Service                   0                 1200
# ...                             ...                 ...                  ...
# 656478                     existing                   0                  NaN
# 656479                          NaN                   0                  NaN
# 656480                          NaN                   0                  NaN
# 656481                          NaN                   0                  NaN
# 656492                          new                   0                  NaN
#
#        plan_rate_from_value plan_rate_to_value plan_rate_amount
# 0                       NaN                NaN             4.40
# 1                       NaN                NaN             4.04
# 2                       NaN                NaN             5.06
# 3                       NaN                NaN             4.23
# 4                       NaN                NaN             5.70
# ...                     ...                ...              ...
# 656478                  NaN                NaN             7.67
# 656479                  NaN                NaN             6.04
# 656480                  NaN                NaN             7.97
# 656481                  NaN                NaN             7.97
# 656492                  NaN                NaN             6.99
#
# [656493 rows x 29 columns]

# %%
# Check for missing 'utility_id' and date columns in df_utility_rates_amounts_sorted
missing_util_id_rates = df_utility_rates_amounts_sorted['utility_id'].isnull().sum()
missing_dates_rates = df_utility_rates_amounts_sorted['created_at'].isnull().sum()
print(f"Missing 'utility_id' in df_utility_rates_amounts_sorted: {missing_util_id_rates}")
print(f"Missing 'utility_created_at' in df_utility_rates_amounts_sorted: {missing_dates_rates}")
# Out:
# Missing 'utility_id' in df_utility_rates_amounts_sorted: 0
# Missing 'utility_created_at' in df_utility_rates_amounts_sorted: 0

# %%
# Check for missing 'utility_id' and date columns in df_utility_plan_rates_amounts_sorted
missing_util_id_plan = df_utility_plan_rates_amounts_sorted['utility_id'].isnull().sum()
missing_dates_plan = df_utility_plan_rates_amounts_sorted['created_at'].isnull().sum()
print(f"\nMissing 'utility_id' in df_utility_plan_rates_amounts_sorted: {missing_util_id_plan}")
print(f"Missing 'plan_rate_created_at' in df_utility_plan_rates_amounts_sorted: {missing_dates_plan}")
# Out:
# Missing 'utility_id' in df_utility_plan_rates_amounts_sorted: 0
# Missing 'plan_rate_created_at' in df_utility_plan_rates_amounts_sorted: 0

# %%
merged_df = pd.merge(
    df_utility_rates_amounts,
    df_utility_plan_rates_amounts,
    how='left',
    on=['utility_id', 'created_at'],
    suffixes=('_utility', '_plan')
)

# %%
merged_df
# Out:
#        utility_id utility_name_utility utility_rate_type created_at  \
# 0               1      Allegheny Power      default rate 1999-07-30
# 1               1      Allegheny Power      default rate 1999-07-30
# 2               1      Allegheny Power      default rate 1999-07-30
# 3               1      Allegheny Power      default rate 1999-07-30
# 4               1      Allegheny Power      default rate 1999-07-30
# ...           ...                  ...               ...        ...
# 48105          10      West Penn Power      default rate 2020-04-06
# 48106          10      West Penn Power      default rate 2020-04-06
# 48107          10      West Penn Power      default rate 2020-04-06
# 48108          10      West Penn Power      default rate 2023-09-14
# 48109          10      West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_value  \
# 0                          NaN                    NaN               3.221
# 1                          NaN                    NaN               3.221
# 2                          NaN                    NaN               3.221
# 3                          NaN                    NaN               3.221
# 4                          NaN                    NaN               3.221
# ...                        ...                    ...                 ...
# 48105                      NaN                    NaN               6.059
# 48106                      NaN                    NaN               6.059
# 48107                      NaN                    NaN               6.059
# 48108                      NaN                    NaN               9.929
# 48109                      NaN                    NaN               9.997
#
#       utility_name_plan  supplier_id          supplier_name  ...  \
# 0       Allegheny Power          1.0            FirstEnergy  ...
# 1       Allegheny Power          2.0  Green Mountain Energy  ...
# 2       Allegheny Power          2.0  Green Mountain Energy  ...
# 3       Allegheny Power          2.0  Green Mountain Energy  ...
# 4       Allegheny Power          2.0  Green Mountain Energy  ...
# ...                 ...          ...                    ...  ...
# 48105   West Penn Power         96.0     Town Square Energy  ...
# 48106   West Penn Power         96.0     Town Square Energy  ...
# 48107   West Penn Power         96.0     Town Square Energy  ...
# 48108               NaN          NaN                    NaN  ...
# 48109               NaN          NaN                    NaN  ...
#
#        term_end_date plan_end_date sq_ft_2600 sq_ft_800  \
# 0                NaN           NaN        NaN       NaN
# 1                NaN           NaN        NaN       NaN
# 2                NaN           NaN        NaN       NaN
# 3                NaN           NaN        NaN       NaN
# 4                NaN           NaN        NaN       NaN
# ...              ...           ...        ...       ...
# 48105            NaN           NaN        NaN       NaN
# 48106            NaN           NaN        NaN       NaN
# 48107            NaN           NaN        NaN       NaN
# 48108            NaN           NaN        NaN       NaN
# 48109            NaN           NaN        NaN       NaN
#
#                          plan_type plan_rate_min_value plan_rate_max_value  \
# 0      Regular Residential Service                 0.0                 NaN
# 1      Regular Residential Service                 0.0                 NaN
# 2      Regular Residential Service                 0.0                1200
# 3      Regular Residential Service              1201.0                 NaN
# 4      Regular Residential Service                 0.0                1200
# ...                            ...                 ...                 ...
# 48105                          NaN                 0.0                 NaN
# 48106                          NaN                 0.0                 NaN
# 48107                          NaN                 0.0                 NaN
# 48108                          NaN                 NaN                 NaN
# 48109                          NaN                 NaN                 NaN
#
#       plan_rate_from_value  plan_rate_to_value plan_rate_amount
# 0                      NaN                 NaN             4.40
# 1                      NaN                 NaN             4.04
# 2                      NaN                 NaN             5.06
# 3                      NaN                 NaN             4.23
# 4                      NaN                 NaN             5.70
# ...                    ...                 ...              ...
# 48105                  NaN                 NaN             5.28
# 48106                  NaN                 NaN             6.76
# 48107                  NaN                 NaN             6.87
# 48108                  NaN                 NaN              NaN
# 48109                  NaN                 NaN              NaN
#
# [48110 rows x 34 columns]

# %%
merged_df.columns
# Out:
# Index(['utility_id', 'utility_name_utility', 'utility_rate_type', 'created_at',
#        'utility_rate_from_value', 'utility_rate_to_value',
#        'utility_rate_value', 'utility_name_plan', 'supplier_id',
#        'supplier_name', 'plan_id', 'state', 'rate_unit', 'contact_number',
#        'is_variable', 'rate_type_plan', 'is_green', 'description', 'term',
#        'website_url', 'green_details', 'green_percentage', 'start_date',
#        'service_type', 'term_end_date', 'plan_end_date', 'sq_ft_2600',
#        'sq_ft_800', 'plan_type', 'plan_rate_min_value', 'plan_rate_max_value',
#        'plan_rate_from_value', 'plan_rate_to_value', 'plan_rate_amount'],
#       dtype='object')

# %%
required_columns = [
    'utility_id',
    'utility_name_utility',
    'utility_rate_type',
    'created_at',
    'utility_rate_from_value',
    'utility_rate_to_value',
    'utility_rate_value',
    'supplier_id',
    'supplier_name',
    'plan_id',
    'state',
    'rate_unit',
    'contact_number',
    'is_variable',
    'rate_type_plan',
    'is_green',
    'description',
    'term',
    'website_url',
    'green_details',
    'green_percentage',
    'start_date',
    'service_type',
    'term_end_date',
    'plan_end_date',
    'sq_ft_2600',
    'sq_ft_800',
    'plan_type',
    'plan_rate_min_value',
    'plan_rate_max_value',
    'plan_rate_from_value',
    'plan_rate_to_value',
    'plan_rate_amount']

# %%
merged_df = merged_df[required_columns].copy()

# %%
merged_df
# Out:
#        utility_id utility_name_utility utility_rate_type created_at  \
# 0               1      Allegheny Power      default rate 1999-07-30
# 1               1      Allegheny Power      default rate 1999-07-30
# 2               1      Allegheny Power      default rate 1999-07-30
# 3               1      Allegheny Power      default rate 1999-07-30
# 4               1      Allegheny Power      default rate 1999-07-30
# ...           ...                  ...               ...        ...
# 48105          10      West Penn Power      default rate 2020-04-06
# 48106          10      West Penn Power      default rate 2020-04-06
# 48107          10      West Penn Power      default rate 2020-04-06
# 48108          10      West Penn Power      default rate 2023-09-14
# 48109          10      West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_value  \
# 0                          NaN                    NaN               3.221
# 1                          NaN                    NaN               3.221
# 2                          NaN                    NaN               3.221
# 3                          NaN                    NaN               3.221
# 4                          NaN                    NaN               3.221
# ...                        ...                    ...                 ...
# 48105                      NaN                    NaN               6.059
# 48106                      NaN                    NaN               6.059
# 48107                      NaN                    NaN               6.059
# 48108                      NaN                    NaN               9.929
# 48109                      NaN                    NaN               9.997
#
#        supplier_id          supplier_name   plan_id  ... term_end_date  \
# 0              1.0            FirstEnergy       1.0  ...           NaN
# 1              2.0  Green Mountain Energy       2.0  ...           NaN
# 2              2.0  Green Mountain Energy       3.0  ...           NaN
# 3              2.0  Green Mountain Energy       3.0  ...           NaN
# 4              2.0  Green Mountain Energy       4.0  ...           NaN
# ...            ...                    ...       ...  ...           ...
# 48105         96.0     Town Square Energy  242820.0  ...           NaN
# 48106         96.0     Town Square Energy  242821.0  ...           NaN
# 48107         96.0     Town Square Energy  242822.0  ...           NaN
# 48108          NaN                    NaN       NaN  ...           NaN
# 48109          NaN                    NaN       NaN  ...           NaN
#
#       plan_end_date sq_ft_2600 sq_ft_800                    plan_type  \
# 0               NaN        NaN       NaN  Regular Residential Service
# 1               NaN        NaN       NaN  Regular Residential Service
# 2               NaN        NaN       NaN  Regular Residential Service
# 3               NaN        NaN       NaN  Regular Residential Service
# 4               NaN        NaN       NaN  Regular Residential Service
# ...             ...        ...       ...                          ...
# 48105           NaN        NaN       NaN                          NaN
# 48106           NaN        NaN       NaN                          NaN
# 48107           NaN        NaN       NaN                          NaN
# 48108           NaN        NaN       NaN                          NaN
# 48109           NaN        NaN       NaN                          NaN
#
#       plan_rate_min_value plan_rate_max_value  plan_rate_from_value  \
# 0                     0.0                 NaN                   NaN
# 1                     0.0                 NaN                   NaN
# 2                     0.0                1200                   NaN
# 3                  1201.0                 NaN                   NaN
# 4                     0.0                1200                   NaN
# ...                   ...                 ...                   ...
# 48105                 0.0                 NaN                   NaN
# 48106                 0.0                 NaN                   NaN
# 48107                 0.0                 NaN                   NaN
# 48108                 NaN                 NaN                   NaN
# 48109                 NaN                 NaN                   NaN
#
#       plan_rate_to_value plan_rate_amount
# 0                    NaN             4.40
# 1                    NaN             4.04
# 2                    NaN             5.06
# 3                    NaN             4.23
# 4                    NaN             5.70
# ...                  ...              ...
# 48105                NaN             5.28
# 48106                NaN             6.76
# 48107                NaN             6.87
# 48108                NaN              NaN
# 48109                NaN              NaN
#
# [48110 rows x 33 columns]

# %%
merged_df.rename(columns={
    'utility_name_utility': 'utility_name',
    'utility_rate_value': 'utility_rate_amount',
}, inplace=True)

# %%
merged_df
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 48105          10  West Penn Power      default rate 2020-04-06
# 48106          10  West Penn Power      default rate 2020-04-06
# 48107          10  West Penn Power      default rate 2020-04-06
# 48108          10  West Penn Power      default rate 2023-09-14
# 48109          10  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 48105                      NaN                    NaN                6.059
# 48106                      NaN                    NaN                6.059
# 48107                      NaN                    NaN                6.059
# 48108                      NaN                    NaN                9.929
# 48109                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ... term_end_date  \
# 0              1.0            FirstEnergy       1.0  ...           NaN
# 1              2.0  Green Mountain Energy       2.0  ...           NaN
# 2              2.0  Green Mountain Energy       3.0  ...           NaN
# 3              2.0  Green Mountain Energy       3.0  ...           NaN
# 4              2.0  Green Mountain Energy       4.0  ...           NaN
# ...            ...                    ...       ...  ...           ...
# 48105         96.0     Town Square Energy  242820.0  ...           NaN
# 48106         96.0     Town Square Energy  242821.0  ...           NaN
# 48107         96.0     Town Square Energy  242822.0  ...           NaN
# 48108          NaN                    NaN       NaN  ...           NaN
# 48109          NaN                    NaN       NaN  ...           NaN
#
#       plan_end_date sq_ft_2600 sq_ft_800                    plan_type  \
# 0               NaN        NaN       NaN  Regular Residential Service
# 1               NaN        NaN       NaN  Regular Residential Service
# 2               NaN        NaN       NaN  Regular Residential Service
# 3               NaN        NaN       NaN  Regular Residential Service
# 4               NaN        NaN       NaN  Regular Residential Service
# ...             ...        ...       ...                          ...
# 48105           NaN        NaN       NaN                          NaN
# 48106           NaN        NaN       NaN                          NaN
# 48107           NaN        NaN       NaN                          NaN
# 48108           NaN        NaN       NaN                          NaN
# 48109           NaN        NaN       NaN                          NaN
#
#       plan_rate_min_value plan_rate_max_value  plan_rate_from_value  \
# 0                     0.0                 NaN                   NaN
# 1                     0.0                 NaN                   NaN
# 2                     0.0                1200                   NaN
# 3                  1201.0                 NaN                   NaN
# 4                     0.0                1200                   NaN
# ...                   ...                 ...                   ...
# 48105                 0.0                 NaN                   NaN
# 48106                 0.0                 NaN                   NaN
# 48107                 0.0                 NaN                   NaN
# 48108                 NaN                 NaN                   NaN
# 48109                 NaN                 NaN                   NaN
#
#       plan_rate_to_value plan_rate_amount
# 0                    NaN             4.40
# 1                    NaN             4.04
# 2                    NaN             5.06
# 3                    NaN             4.23
# 4                    NaN             5.70
# ...                  ...              ...
# 48105                NaN             5.28
# 48106                NaN             6.76
# 48107                NaN             6.87
# 48108                NaN              NaN
# 48109                NaN              NaN
#
# [48110 rows x 33 columns]

# %%
dataset_with_benefits = pd.merge(merged_df, df_benefits, on="plan_id", how="left")

# %%
drop_columns = [
    "benefit_id",
    ]
dataset_with_benefits.drop(columns=drop_columns, inplace=True)

# %%
dataset_with_benefits.rename(columns={
    'value': 'benefits_value',
}, inplace=True)

# %%
dataset_with_benefits
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 48392          10  West Penn Power      default rate 2020-04-06
# 48393          10  West Penn Power      default rate 2020-04-06
# 48394          10  West Penn Power      default rate 2020-04-06
# 48395          10  West Penn Power      default rate 2023-09-14
# 48396          10  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 48392                      NaN                    NaN                6.059
# 48393                      NaN                    NaN                6.059
# 48394                      NaN                    NaN                6.059
# 48395                      NaN                    NaN                9.929
# 48396                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ... sq_ft_2600 sq_ft_800  \
# 0              1.0            FirstEnergy       1.0  ...        NaN       NaN
# 1              2.0  Green Mountain Energy       2.0  ...        NaN       NaN
# 2              2.0  Green Mountain Energy       3.0  ...        NaN       NaN
# 3              2.0  Green Mountain Energy       3.0  ...        NaN       NaN
# 4              2.0  Green Mountain Energy       4.0  ...        NaN       NaN
# ...            ...                    ...       ...  ...        ...       ...
# 48392         96.0     Town Square Energy  242820.0  ...        NaN       NaN
# 48393         96.0     Town Square Energy  242821.0  ...        NaN       NaN
# 48394         96.0     Town Square Energy  242822.0  ...        NaN       NaN
# 48395          NaN                    NaN       NaN  ...        NaN       NaN
# 48396          NaN                    NaN       NaN  ...        NaN       NaN
#
#                          plan_type plan_rate_min_value plan_rate_max_value  \
# 0      Regular Residential Service                 0.0                 NaN
# 1      Regular Residential Service                 0.0                 NaN
# 2      Regular Residential Service                 0.0                1200
# 3      Regular Residential Service              1201.0                 NaN
# 4      Regular Residential Service                 0.0                1200
# ...                            ...                 ...                 ...
# 48392                          NaN                 0.0                 NaN
# 48393                          NaN                 0.0                 NaN
# 48394                          NaN                 0.0                 NaN
# 48395                          NaN                 NaN                 NaN
# 48396                          NaN                 NaN                 NaN
#
#       plan_rate_from_value plan_rate_to_value  plan_rate_amount benefit_type  \
# 0                      NaN                NaN              4.40          NaN
# 1                      NaN                NaN              4.04          NaN
# 2                      NaN                NaN              5.06          NaN
# 3                      NaN                NaN              4.23          NaN
# 4                      NaN                NaN              5.70          NaN
# ...                    ...                ...               ...          ...
# 48392                  NaN                NaN              5.28          NaN
# 48393                  NaN                NaN              6.76          NaN
# 48394                  NaN                NaN              6.87          NaN
# 48395                  NaN                NaN               NaN          NaN
# 48396                  NaN                NaN               NaN          NaN
#
#       benefits_value
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 48392            NaN
# 48393            NaN
# 48394            NaN
# 48395            NaN
# 48396            NaN
#
# [48397 rows x 35 columns]

# %%
df_amounts
# Out:
#          amount_id  from_value  to_value  value   rate_id  usage_credit_id  \
# 0                1         NaN       NaN  3.221       1.0              NaN
# 1                2         NaN       NaN  4.400       2.0              NaN
# 2                3         NaN       NaN  0.000       NaN              1.0
# 3                4         NaN       NaN  4.040       3.0              NaN
# 4                5         NaN       NaN  0.000       NaN              2.0
# ...            ...         ...       ...    ...       ...              ...
# 1773977    1773978         NaN       NaN  6.369  659498.0              NaN
# 1773978    1773979         NaN       NaN  6.405  659499.0              NaN
# 1773979    1773980         NaN       NaN  6.369  659500.0              NaN
# 1773980    1773981         NaN       NaN  8.917  659501.0              NaN
# 1773981    1773982         NaN       NaN  9.425  659502.0              NaN
#
#          monthly_charge_id
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 1773977                NaN
# 1773978                NaN
# 1773979                NaN
# 1773980                NaN
# 1773981                NaN
#
# [1773982 rows x 7 columns]

# %%
df_monthly_charges_amounts = pd.merge(df_monthly_charges, df_amounts, on="monthly_charge_id", how="left")
drop_columns = [
    "monthly_charge_id",
    "amount_id",
    "rate_id",
    "usage_credit_id"
]

# %%
df_monthly_charges_amounts.columns
# Out:
# Index(['monthly_charge_id', 'min_value', 'max_value', 'plan_id', 'amount_id',
#        'from_value', 'to_value', 'value', 'rate_id', 'usage_credit_id'],
#       dtype='object')

# %%
df_monthly_charges_amounts.drop(columns=drop_columns, inplace=True)

# %%
df_monthly_charges_amounts.rename(columns={
    "value": "monthly_charge_amount",
    "min_value": "monthly_charge_min_value",
    "max_value": "monthly_charge_max_value",
    "from_value": "monthly_charge_from_value",
    "to_value": "monthly_charge_to_value"
}, inplace=True)

# %%
df_monthly_charges_amounts.columns
# Out:
# Index(['monthly_charge_min_value', 'monthly_charge_max_value', 'plan_id',
#        'monthly_charge_from_value', 'monthly_charge_to_value',
#        'monthly_charge_amount'],
#       dtype='object')

# %%
dataset_with_monthly_charges = pd.merge(dataset_with_benefits, df_monthly_charges_amounts, on="plan_id", how="left")

# %%
dataset_with_monthly_charges
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 48392          10  West Penn Power      default rate 2020-04-06
# 48393          10  West Penn Power      default rate 2020-04-06
# 48394          10  West Penn Power      default rate 2020-04-06
# 48395          10  West Penn Power      default rate 2023-09-14
# 48396          10  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 48392                      NaN                    NaN                6.059
# 48393                      NaN                    NaN                6.059
# 48394                      NaN                    NaN                6.059
# 48395                      NaN                    NaN                9.929
# 48396                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ... plan_rate_from_value  \
# 0              1.0            FirstEnergy       1.0  ...                  NaN
# 1              2.0  Green Mountain Energy       2.0  ...                  NaN
# 2              2.0  Green Mountain Energy       3.0  ...                  NaN
# 3              2.0  Green Mountain Energy       3.0  ...                  NaN
# 4              2.0  Green Mountain Energy       4.0  ...                  NaN
# ...            ...                    ...       ...  ...                  ...
# 48392         96.0     Town Square Energy  242820.0  ...                  NaN
# 48393         96.0     Town Square Energy  242821.0  ...                  NaN
# 48394         96.0     Town Square Energy  242822.0  ...                  NaN
# 48395          NaN                    NaN       NaN  ...                  NaN
# 48396          NaN                    NaN       NaN  ...                  NaN
#
#       plan_rate_to_value plan_rate_amount benefit_type benefits_value  \
# 0                    NaN             4.40          NaN            NaN
# 1                    NaN             4.04          NaN            NaN
# 2                    NaN             5.06          NaN            NaN
# 3                    NaN             4.23          NaN            NaN
# 4                    NaN             5.70          NaN            NaN
# ...                  ...              ...          ...            ...
# 48392                NaN             5.28          NaN            NaN
# 48393                NaN             6.76          NaN            NaN
# 48394                NaN             6.87          NaN            NaN
# 48395                NaN              NaN          NaN            NaN
# 48396                NaN              NaN          NaN            NaN
#
#       monthly_charge_min_value monthly_charge_max_value  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 48392                      0.0                      NaN
# 48393                      0.0                      NaN
# 48394                      0.0                      NaN
# 48395                      NaN                      NaN
# 48396                      NaN                      NaN
#
#        monthly_charge_from_value monthly_charge_to_value monthly_charge_amount
# 0                            NaN                     NaN                   NaN
# 1                            NaN                     NaN                   NaN
# 2                            NaN                     NaN                   NaN
# 3                            NaN                     NaN                   NaN
# 4                            NaN                     NaN                   NaN
# ...                          ...                     ...                   ...
# 48392                        NaN                     NaN                   0.0
# 48393                        NaN                     NaN                   0.0
# 48394                        NaN                     NaN                   0.0
# 48395                        NaN                     NaN                   NaN
# 48396                        NaN                     NaN                   NaN
#
# [48397 rows x 40 columns]

# %%
drop_columns = [
    "usage_credit_id",
]
df_usage_credits.drop(columns=drop_columns, inplace=True)

# %%
df_usage_credits.rename(columns=({
    "min_value": "usage_credit_min_value",
    "max_value": "usage_credit_max_value",
}), inplace=True)

# %%
dataset_with_usage_credits = pd.merge(dataset_with_monthly_charges, df_usage_credits, on="plan_id", how="left")

# %%
dataset_with_usage_credits
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 48392          10  West Penn Power      default rate 2020-04-06
# 48393          10  West Penn Power      default rate 2020-04-06
# 48394          10  West Penn Power      default rate 2020-04-06
# 48395          10  West Penn Power      default rate 2023-09-14
# 48396          10  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 48392                      NaN                    NaN                6.059
# 48393                      NaN                    NaN                6.059
# 48394                      NaN                    NaN                6.059
# 48395                      NaN                    NaN                9.929
# 48396                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ... plan_rate_amount  \
# 0              1.0            FirstEnergy       1.0  ...             4.40
# 1              2.0  Green Mountain Energy       2.0  ...             4.04
# 2              2.0  Green Mountain Energy       3.0  ...             5.06
# 3              2.0  Green Mountain Energy       3.0  ...             4.23
# 4              2.0  Green Mountain Energy       4.0  ...             5.70
# ...            ...                    ...       ...  ...              ...
# 48392         96.0     Town Square Energy  242820.0  ...             5.28
# 48393         96.0     Town Square Energy  242821.0  ...             6.76
# 48394         96.0     Town Square Energy  242822.0  ...             6.87
# 48395          NaN                    NaN       NaN  ...              NaN
# 48396          NaN                    NaN       NaN  ...              NaN
#
#       benefit_type benefits_value monthly_charge_min_value  \
# 0              NaN            NaN                      NaN
# 1              NaN            NaN                      NaN
# 2              NaN            NaN                      NaN
# 3              NaN            NaN                      NaN
# 4              NaN            NaN                      NaN
# ...            ...            ...                      ...
# 48392          NaN            NaN                      0.0
# 48393          NaN            NaN                      0.0
# 48394          NaN            NaN                      0.0
# 48395          NaN            NaN                      NaN
# 48396          NaN            NaN                      NaN
#
#       monthly_charge_max_value monthly_charge_from_value  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 48392                      NaN                       NaN
# 48393                      NaN                       NaN
# 48394                      NaN                       NaN
# 48395                      NaN                       NaN
# 48396                      NaN                       NaN
#
#       monthly_charge_to_value  monthly_charge_amount usage_credit_min_value  \
# 0                         NaN                    NaN                    0.0
# 1                         NaN                    NaN                    0.0
# 2                         NaN                    NaN                    0.0
# 3                         NaN                    NaN                    0.0
# 4                         NaN                    NaN                    0.0
# ...                       ...                    ...                    ...
# 48392                     NaN                    0.0                    0.0
# 48393                     NaN                    0.0                    0.0
# 48394                     NaN                    0.0                    0.0
# 48395                     NaN                    NaN                    NaN
# 48396                     NaN                    NaN                    NaN
#
#       usage_credit_max_value
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 48392                    NaN
# 48393                    NaN
# 48394                    NaN
# 48395                    NaN
# 48396                    NaN
#
# [48397 rows x 42 columns]

# %%
df_early_term_fees
# Out:
#         early_term_fee_id  min_value  max_value  fee_type  term  plan_id
# 0                       1        0.0        NaN       NaN   NaN     5123
# 1                       2        0.0        NaN       NaN   NaN     5125
# 2                       3        0.0        NaN       NaN   NaN     5126
# 3                       4        0.0        NaN       NaN   NaN     5127
# 4                       5        0.0        NaN       NaN   NaN     5131
# ...                   ...        ...        ...       ...   ...      ...
# 533229             533230        0.0        NaN  straight   NaN   656737
# 533230             533231        0.0        NaN  straight   NaN   656738
# 533231             533232        0.0        NaN  straight   NaN   656739
# 533232             533233    12500.0        NaN  straight   NaN   656740
# 533233             533234        0.0        NaN  straight   NaN   656741
#
# [533234 rows x 6 columns]

# %%
drop_columns = [
    "early_term_fee_id",
]
df_early_term_fees.drop(columns=drop_columns, inplace=True)

df_early_term_fees.rename(columns=({
    "min_value": "early_term_fees_min_value",
    "max_value": "early_term_fees_max_value",
    "fee_type": "early_term_fee_type",
    "term": "early_term_fee_term"
}), inplace=True)

# %%
dataset_with_early_term_fees = pd.merge(dataset_with_usage_credits, df_early_term_fees, on="plan_id", how="left")

# %%
dataset_with_early_term_fees
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 48392          10  West Penn Power      default rate 2020-04-06
# 48393          10  West Penn Power      default rate 2020-04-06
# 48394          10  West Penn Power      default rate 2020-04-06
# 48395          10  West Penn Power      default rate 2023-09-14
# 48396          10  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 48392                      NaN                    NaN                6.059
# 48393                      NaN                    NaN                6.059
# 48394                      NaN                    NaN                6.059
# 48395                      NaN                    NaN                9.929
# 48396                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ...  \
# 0              1.0            FirstEnergy       1.0  ...
# 1              2.0  Green Mountain Energy       2.0  ...
# 2              2.0  Green Mountain Energy       3.0  ...
# 3              2.0  Green Mountain Energy       3.0  ...
# 4              2.0  Green Mountain Energy       4.0  ...
# ...            ...                    ...       ...  ...
# 48392         96.0     Town Square Energy  242820.0  ...
# 48393         96.0     Town Square Energy  242821.0  ...
# 48394         96.0     Town Square Energy  242822.0  ...
# 48395          NaN                    NaN       NaN  ...
# 48396          NaN                    NaN       NaN  ...
#
#       monthly_charge_max_value monthly_charge_from_value  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 48392                      NaN                       NaN
# 48393                      NaN                       NaN
# 48394                      NaN                       NaN
# 48395                      NaN                       NaN
# 48396                      NaN                       NaN
#
#       monthly_charge_to_value monthly_charge_amount usage_credit_min_value  \
# 0                         NaN                   NaN                    0.0
# 1                         NaN                   NaN                    0.0
# 2                         NaN                   NaN                    0.0
# 3                         NaN                   NaN                    0.0
# 4                         NaN                   NaN                    0.0
# ...                       ...                   ...                    ...
# 48392                     NaN                   0.0                    0.0
# 48393                     NaN                   0.0                    0.0
# 48394                     NaN                   0.0                    0.0
# 48395                     NaN                   NaN                    NaN
# 48396                     NaN                   NaN                    NaN
#
#       usage_credit_max_value early_term_fees_min_value  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ...                      ...                       ...
# 48392                    NaN                       NaN
# 48393                    NaN                       NaN
# 48394                    NaN                    5000.0
# 48395                    NaN                       NaN
# 48396                    NaN                       NaN
#
#        early_term_fees_max_value early_term_fee_type early_term_fee_term
# 0                            NaN                 NaN                 NaN
# 1                            NaN                 NaN                 NaN
# 2                            NaN                 NaN                 NaN
# 3                            NaN                 NaN                 NaN
# 4                            NaN                 NaN                 NaN
# ...                          ...                 ...                 ...
# 48392                        NaN                 NaN                 NaN
# 48393                        NaN                 NaN                 NaN
# 48394                        NaN            straight                 NaN
# 48395                        NaN                 NaN                 NaN
# 48396                        NaN                 NaN                 NaN
#
# [48397 rows x 46 columns]

# %%
dataset_with_early_term_fees.drop(columns=["plan_id","supplier_id"], inplace=True)

# %%
dataset_with_early_term_fees
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 48392          10  West Penn Power      default rate 2020-04-06
# 48393          10  West Penn Power      default rate 2020-04-06
# 48394          10  West Penn Power      default rate 2020-04-06
# 48395          10  West Penn Power      default rate 2023-09-14
# 48396          10  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 48392                      NaN                    NaN                6.059
# 48393                      NaN                    NaN                6.059
# 48394                      NaN                    NaN                6.059
# 48395                      NaN                    NaN                9.929
# 48396                      NaN                    NaN                9.997
#
#                supplier_name state rate_unit  ... monthly_charge_max_value  \
# 0                FirstEnergy    pa       kWh  ...                      NaN
# 1      Green Mountain Energy    pa       kWh  ...                      NaN
# 2      Green Mountain Energy    pa       kWh  ...                      NaN
# 3      Green Mountain Energy    pa       kWh  ...                      NaN
# 4      Green Mountain Energy    pa       kWh  ...                      NaN
# ...                      ...   ...       ...  ...                      ...
# 48392     Town Square Energy    pa       kWh  ...                      NaN
# 48393     Town Square Energy    pa       kWh  ...                      NaN
# 48394     Town Square Energy    pa       kWh  ...                      NaN
# 48395                    NaN   NaN       NaN  ...                      NaN
# 48396                    NaN   NaN       NaN  ...                      NaN
#
#       monthly_charge_from_value monthly_charge_to_value monthly_charge_amount  \
# 0                           NaN                     NaN                   NaN
# 1                           NaN                     NaN                   NaN
# 2                           NaN                     NaN                   NaN
# 3                           NaN                     NaN                   NaN
# 4                           NaN                     NaN                   NaN
# ...                         ...                     ...                   ...
# 48392                       NaN                     NaN                   0.0
# 48393                       NaN                     NaN                   0.0
# 48394                       NaN                     NaN                   0.0
# 48395                       NaN                     NaN                   NaN
# 48396                       NaN                     NaN                   NaN
#
#       usage_credit_min_value  usage_credit_max_value  \
# 0                        0.0                     NaN
# 1                        0.0                     NaN
# 2                        0.0                     NaN
# 3                        0.0                     NaN
# 4                        0.0                     NaN
# ...                      ...                     ...
# 48392                    0.0                     NaN
# 48393                    0.0                     NaN
# 48394                    0.0                     NaN
# 48395                    NaN                     NaN
# 48396                    NaN                     NaN
#
#       early_term_fees_min_value early_term_fees_max_value  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 48392                       NaN                       NaN
# 48393                       NaN                       NaN
# 48394                    5000.0                       NaN
# 48395                       NaN                       NaN
# 48396                       NaN                       NaN
#
#        early_term_fee_type early_term_fee_term
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ...                    ...                 ...
# 48392                  NaN                 NaN
# 48393                  NaN                 NaN
# 48394             straight                 NaN
# 48395                  NaN                 NaN
# 48396                  NaN                 NaN
#
# [48397 rows x 44 columns]

# %%
try:
  pickle_file_path = 'WattBuyData1999_2024.pkl'
  dataset_with_early_term_fees.to_pickle(pickle_file_path)
  print(f"DataFrame successfully saved as '{pickle_file_path}'.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# DataFrame successfully saved as 'WattBuyData1999_2024.pkl'.
