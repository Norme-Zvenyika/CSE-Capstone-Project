# %%
import pandas as pd

# %%
# Load all CSV files into dataframes
df_utilities = pd.read_csv('/content/drive/MyDrive/CSE 280/utilities.csv', low_memory=False)
df_suppliers = pd.read_csv('/content/drive/MyDrive/CSE 280/suppliers.csv', low_memory=False)
df_plans = pd.read_csv('/content/drive/MyDrive/CSE 280/plans.csv', low_memory=False)
df_rates = pd.read_csv('/content/drive/MyDrive/CSE 280/rates.csv', low_memory=False)
df_amounts = pd.read_csv('/content/drive/MyDrive/CSE 280/amounts.csv', low_memory=False)
df_monthly_charges = pd.read_csv('/content/drive/MyDrive/CSE 280/monthly_charges.csv', low_memory=False)
df_usage_credits = pd.read_csv('/content/drive/MyDrive/CSE 280/usage_credits.csv', low_memory=False)
df_early_term_fees = pd.read_csv('/content/drive/MyDrive/CSE 280/early_term_fees.csv', low_memory=False)
df_benefits = pd.read_csv('/content/drive/MyDrive/CSE 280/benefits.csv', low_memory=False)

# %%
df_utilities.rename(columns={'id': 'utility_id', 'name': 'utility_name'}, inplace=True)
df_suppliers.rename(columns={'id': 'supplier_id', 'name': 'supplier_name'}, inplace=True)
df_plans.rename(columns={'id': 'plan_id'}, inplace=True)
df_rates.rename(columns={'id': 'rate_id'}, inplace=True)
df_amounts.rename(columns={'id': 'amount_id'}, inplace=True)
df_monthly_charges.rename(columns={'id': 'monthly_charge_id'}, inplace=True)
df_usage_credits.rename(columns={'id': 'usage_credit_id'}, inplace=True)
df_early_term_fees.rename(columns={'id': 'early_term_fee_id'}, inplace=True)
df_benefits.rename(columns={'id': 'benefit_id'}, inplace=True)

# %%
df_plans_missing = df_plans [df_plans ['created_at'].isnull()]
df_plans_missing
# Out:
#        plan_id created_at state rate_unit  contact_number is_variable  \
# 7645      7646        NaN    pa       kWh  1-888-313-9086       False
# 10153    10154        NaN    pa       kWh             NaN        True
# 10154    10155        NaN    pa       kWh             NaN         NaN
# 10155    10156        NaN    pa       kWh             NaN         NaN
# 10156    10157        NaN    pa       kWh             NaN         NaN
#
#       rate_type is_green description  term  ...  green_details  \
# 7645      fixed    False         NaN   6.0  ...  25% renewable
# 10153  variable    False         NaN   NaN  ...            NaN
# 10154     fixed    False         NaN   NaN  ...            NaN
# 10155     fixed    False         NaN   NaN  ...            NaN
# 10156     fixed     True         NaN  12.0  ...           wind
#
#       green_percentage  start_date service_type term_end_date plan_end_date  \
# 7645              25.0         NaN  Residential           NaN           NaN
# 10153              NaN         NaN          NaN           NaN           NaN
# 10154              NaN         NaN          NaN           NaN           NaN
# 10155              NaN         NaN          NaN           NaN           NaN
# 10156            100.0         NaN          NaN           NaN           NaN
#
#       sq_ft_2600  sq_ft_800                    plan_type supplier_id
# 7645         NaN        NaN                          NaN          27
# 10153        NaN        NaN  Regular Residential Service          53
# 10154        NaN        NaN  Regular Residential Service          53
# 10155        NaN        NaN  Regular Residential Service          53
# 10156        NaN        NaN  Regular Residential Service          53
#
# [5 rows x 21 columns]

# %%
df_rates_missing = df_rates [df_rates ['createdAt'].isnull()]
df_rates_missing
# Out:
#        rate_id rate_type  min_value max_value  utility_id  plan_id createdAt
# 7800      7801       NaN          0       NaN         NaN   7646.0       NaN
# 10288    10289       NaN          0       NaN         NaN  10154.0       NaN
# 10289    10290       NaN          0       NaN         NaN  10155.0       NaN
# 10290    10291       NaN          0       NaN         NaN  10156.0       NaN
# 10291    10292       NaN          0       NaN         NaN  10157.0       NaN

# %%
# drop plans with missing created_at column
df_plans = df_plans.dropna(subset=['created_at'])
df_rates = df_rates.dropna(subset=['createdAt'])

# %%
# Add 'rate_source' column to df_rates
df_rates['rate_source'] = df_rates.apply(
    lambda x: 'utility_rate' if pd.notnull(x['utility_id']) else 'plan_rate', axis=1
)

# %%
# Split df_rates into utility rates and plan rates
df_utility_rates = df_rates[df_rates['rate_source'] == 'utility_rate']
df_plan_rates = df_rates[df_rates['rate_source'] == 'plan_rate']

# %%
# Merge df_plan_rates with df_plans
df_plan_rates = df_plan_rates.merge(df_plans, how='left', on='plan_id', suffixes=('', '_plan'))

# %%
# merge df_plan_rates with df_suppliers on 'supplier_id'
df_plan_rates = df_plan_rates.merge(df_suppliers[['supplier_id', 'supplier_name', 'utility_id']], how='left', on='supplier_id')

# %%
df_plan_rates.rename(columns={
    'utility_id_y': 'utility_id',
}, inplace=True)

# %%
# add utility name and utility names
df_plan_rates = df_plan_rates.merge(df_utilities[['utility_id', 'utility_name']], how='left', on='utility_id')

# %%
missing_plan_dates_df= df_plan_rates [df_plan_rates ['createdAt'].isnull()]

# Display the filtered DataFrame
print("Plans with missing 'plan_rate_created_at':")
missing_plan_dates_df
# Out:
# Plans with missing 'plan_rate_created_at':
# Empty DataFrame
# Columns: [rate_id, rate_type, min_value, max_value, utility_id_x, plan_id, createdAt, rate_source, created_at, state, rate_unit, contact_number, is_variable, rate_type_plan, is_green, description, term, website_url, green_details, green_percentage, start_date, service_type, term_end_date, plan_end_date, sq_ft_2600, sq_ft_800, plan_type, supplier_id, supplier_name, utility_id, utility_name]
# Index: []
#
# [0 rows x 31 columns]

# %%
# drop rows that have a missing

# %%
# get amounts associated with plan rates
df_amounts_plan = df_amounts[df_amounts['rate_id'].isin(df_plan_rates['rate_id'])]

# %%
# Merge amounts with plan rates
df_plan_rates = df_plan_rates.merge(df_amounts_plan, how='left', on='rate_id')

# %%
df_plan_rates.rename(columns={'value': 'plan_rate_amount'}, inplace=True)

# %%
df_plan_rates
# Out:
#         rate_id rate_type  min_value max_value  utility_id_x   plan_id  \
# 0             2       NaN          0       NaN           NaN       1.0
# 1             3       NaN          0       NaN           NaN       2.0
# 2             4       NaN          0      1200           NaN       3.0
# 3             5       NaN       1201       NaN           NaN       3.0
# 4             6       NaN          0      1200           NaN       4.0
# ...         ...       ...        ...       ...           ...       ...
# 637360   637631       NaN          0       NaN           NaN  637688.0
# 637361   637632       NaN          0       NaN           NaN  637689.0
# 637362   637633       NaN          0       NaN           NaN  637690.0
# 637363   637634       NaN          0       NaN           NaN  637691.0
# 637364   637635       NaN          0       NaN           NaN  637692.0
#
#          createdAt rate_source  created_at state  ... supplier_id  \
# 0       1999-07-30   plan_rate  1999-07-30    pa  ...           1
# 1       1999-07-30   plan_rate  1999-07-30    pa  ...           2
# 2       1999-07-30   plan_rate  1999-07-30    pa  ...           2
# 3       1999-07-30   plan_rate  1999-07-30    pa  ...           2
# 4       1999-07-30   plan_rate  1999-07-30    pa  ...           2
# ...            ...         ...         ...   ...  ...         ...
# 637360  2021-07-21   plan_rate  2021-07-21    pa  ...          22
# 637361  2021-07-21   plan_rate  2021-07-21    pa  ...          22
# 637362  2021-07-21   plan_rate  2021-07-21    pa  ...          65
# 637363  2021-07-21   plan_rate  2021-07-21    pa  ...          65
# 637364  2021-07-21   plan_rate  2021-07-21    pa  ...         111
#
#                 supplier_name utility_id     utility_name  amount_id  \
# 0                 FirstEnergy          1  Allegheny Power        2.0
# 1       Green Mountain Energy          1  Allegheny Power        4.0
# 2       Green Mountain Energy          1  Allegheny Power        6.0
# 3       Green Mountain Energy          1  Allegheny Power        7.0
# 4       Green Mountain Energy          1  Allegheny Power        9.0
# ...                       ...        ...              ...        ...
# 637360           Ambit Energy          2   Duquesne Light  1732120.0
# 637361           Ambit Energy          2   Duquesne Light  1732123.0
# 637362         Energy Rewards          5          Penelec  1732126.0
# 637363         Energy Rewards          5          Penelec  1732129.0
# 637364       Clean Sky Energy          9  West Penn Power  1732132.0
#
#        from_value  to_value plan_rate_amount usage_credit_id  \
# 0             NaN       NaN             4.40             NaN
# 1             NaN       NaN             4.04             NaN
# 2             NaN       NaN             5.06             NaN
# 3             NaN       NaN             4.23             NaN
# 4             NaN       NaN             5.70             NaN
# ...           ...       ...              ...             ...
# 637360        NaN       NaN             6.95             NaN
# 637361        NaN       NaN             6.95             NaN
# 637362        NaN       NaN             8.69             NaN
# 637363        NaN       NaN             8.59             NaN
# 637364        NaN       NaN             6.99             NaN
#
#         monthly_charge_id
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# ...                   ...
# 637360                NaN
# 637361                NaN
# 637362                NaN
# 637363                NaN
# 637364                NaN
#
# [637365 rows x 37 columns]

# %%
df_plan_rates.columns
# Out:
# Index(['rate_id', 'rate_type', 'min_value', 'max_value', 'utility_id_x',
#        'plan_id', 'createdAt', 'rate_source', 'created_at', 'state',
#        'rate_unit', 'contact_number', 'is_variable', 'rate_type_plan',
#        'is_green', 'description', 'term', 'website_url', 'green_details',
#        'green_percentage', 'start_date', 'service_type', 'term_end_date',
#        'plan_end_date', 'sq_ft_2600', 'sq_ft_800', 'plan_type', 'supplier_id',
#        'supplier_name', 'utility_id', 'utility_name', 'amount_id',
#        'from_value', 'to_value', 'plan_rate_amount', 'usage_credit_id',
#        'monthly_charge_id'],
#       dtype='object')

# %%
# Specify the columns to drop as a list
columns_to_drop = ['rate_id', 'rate_type', 'utility_id_x', 'rate_source',
        'amount_id', 'usage_credit_id','created_at','monthly_charge_id']

# %%
# Drop the columns and update the DataFrame in place
df_plan_rates.drop(columns=columns_to_drop, inplace=True)

# %%
df_plan_rates
# Out:
#         min_value max_value   plan_id   createdAt state rate_unit  \
# 0               0       NaN       1.0  1999-07-30    pa       kWh
# 1               0       NaN       2.0  1999-07-30    pa       kWh
# 2               0      1200       3.0  1999-07-30    pa       kWh
# 3            1201       NaN       3.0  1999-07-30    pa       kWh
# 4               0      1200       4.0  1999-07-30    pa       kWh
# ...           ...       ...       ...         ...   ...       ...
# 637360          0       NaN  637688.0  2021-07-21    pa       kWh
# 637361          0       NaN  637689.0  2021-07-21    pa       kWh
# 637362          0       NaN  637690.0  2021-07-21    pa       kWh
# 637363          0       NaN  637691.0  2021-07-21    pa       kWh
# 637364          0       NaN  637692.0  2021-07-21    pa       kWh
#
#        contact_number is_variable rate_type_plan is_green  ... sq_ft_2600  \
# 0        888-254-9227        True       variable    False  ...        NaN
# 1        888-246-6730        True       variable    False  ...        NaN
# 2        888-246-6730        True       variable    False  ...        NaN
# 3        888-246-6730        True       variable    False  ...        NaN
# 4        888-246-6730        True       variable     True  ...        NaN
# ...               ...         ...            ...      ...  ...        ...
# 637360            NaN         NaN          fixed    False  ...       6.95
# 637361            NaN         NaN          fixed    False  ...       6.95
# 637362            NaN         NaN          fixed    False  ...       8.69
# 637363            NaN         NaN          fixed    False  ...       8.59
# 637364            NaN         NaN          fixed    False  ...       6.99
#
#         sq_ft_800                    plan_type supplier_id  \
# 0             NaN  Regular Residential Service           1
# 1             NaN  Regular Residential Service           2
# 2             NaN  Regular Residential Service           2
# 3             NaN  Regular Residential Service           2
# 4             NaN  Regular Residential Service           2
# ...           ...                          ...         ...
# 637360       6.95                          NaN          22
# 637361       6.95                          NaN          22
# 637362       8.69                          NaN          65
# 637363       8.59                          NaN          65
# 637364       6.99                          new         111
#
#                 supplier_name utility_id     utility_name from_value to_value  \
# 0                 FirstEnergy          1  Allegheny Power        NaN      NaN
# 1       Green Mountain Energy          1  Allegheny Power        NaN      NaN
# 2       Green Mountain Energy          1  Allegheny Power        NaN      NaN
# 3       Green Mountain Energy          1  Allegheny Power        NaN      NaN
# 4       Green Mountain Energy          1  Allegheny Power        NaN      NaN
# ...                       ...        ...              ...        ...      ...
# 637360           Ambit Energy          2   Duquesne Light        NaN      NaN
# 637361           Ambit Energy          2   Duquesne Light        NaN      NaN
# 637362         Energy Rewards          5          Penelec        NaN      NaN
# 637363         Energy Rewards          5          Penelec        NaN      NaN
# 637364       Clean Sky Energy          9  West Penn Power        NaN      NaN
#
#         plan_rate_amount
# 0                   4.40
# 1                   4.04
# 2                   5.06
# 3                   4.23
# 4                   5.70
# ...                  ...
# 637360              6.95
# 637361              6.95
# 637362              8.69
# 637363              8.59
# 637364              6.99
#
# [637365 rows x 29 columns]

# %%
# Rename columns to include 'plan_rate_' prefix
df_plan_rates.rename(columns={
    'min_value': 'plan_rate_min_value',
    'max_value': 'plan_rate_max_value',
    'createdAt': 'created_at',
    'from_value': 'plan_rate_from_value',
    'to_value': 'plan_rate_to_value'
}, inplace=True)

# %%
df_plan_rates.columns
# Out:
# Index(['plan_rate_min_value', 'plan_rate_max_value', 'plan_id', 'created_at',
#        'state', 'rate_unit', 'contact_number', 'is_variable', 'rate_type_plan',
#        'is_green', 'description', 'term', 'website_url', 'green_details',
#        'green_percentage', 'start_date', 'service_type', 'term_end_date',
#        'plan_end_date', 'sq_ft_2600', 'sq_ft_800', 'plan_type', 'supplier_id',
#        'supplier_name', 'utility_id', 'utility_name', 'plan_rate_from_value',
#        'plan_rate_to_value', 'plan_rate_amount'],
#       dtype='object')

# %%
# Define the columns to keep
plan_columns = [
    'utility_id',
    'utility_name',
    'supplier_id',
    'supplier_name',
    'plan_id',
    'created_at',
    'state',
    'rate_unit',
    'contact_number',
    'is_variable',
    'rate_type_plan',
    'is_green',
    'description',
    'term',
    'website_url',
    'green_details',
    'green_percentage',
    'start_date',
    'service_type',
    'term_end_date',
    'plan_end_date',
    'sq_ft_2600',
    'sq_ft_800',
    'plan_type',
    'plan_rate_min_value',
    'plan_rate_max_value',
    'plan_rate_from_value',
    'plan_rate_to_value',
    'plan_rate_amount',
]

# %%
# Select the columns
df_utility_plan_rates_amounts = df_plan_rates[plan_columns]

# %%
df_utility_plan_rates_amounts
# Out:
#         utility_id     utility_name  supplier_id          supplier_name  \
# 0                1  Allegheny Power            1            FirstEnergy
# 1                1  Allegheny Power            2  Green Mountain Energy
# 2                1  Allegheny Power            2  Green Mountain Energy
# 3                1  Allegheny Power            2  Green Mountain Energy
# 4                1  Allegheny Power            2  Green Mountain Energy
# ...            ...              ...          ...                    ...
# 637360           2   Duquesne Light           22           Ambit Energy
# 637361           2   Duquesne Light           22           Ambit Energy
# 637362           5          Penelec           65         Energy Rewards
# 637363           5          Penelec           65         Energy Rewards
# 637364           9  West Penn Power          111       Clean Sky Energy
#
#          plan_id  created_at state rate_unit contact_number is_variable  ...  \
# 0            1.0  1999-07-30    pa       kWh   888-254-9227        True  ...
# 1            2.0  1999-07-30    pa       kWh   888-246-6730        True  ...
# 2            3.0  1999-07-30    pa       kWh   888-246-6730        True  ...
# 3            3.0  1999-07-30    pa       kWh   888-246-6730        True  ...
# 4            4.0  1999-07-30    pa       kWh   888-246-6730        True  ...
# ...          ...         ...   ...       ...            ...         ...  ...
# 637360  637688.0  2021-07-21    pa       kWh            NaN         NaN  ...
# 637361  637689.0  2021-07-21    pa       kWh            NaN         NaN  ...
# 637362  637690.0  2021-07-21    pa       kWh            NaN         NaN  ...
# 637363  637691.0  2021-07-21    pa       kWh            NaN         NaN  ...
# 637364  637692.0  2021-07-21    pa       kWh            NaN         NaN  ...
#
#        term_end_date plan_end_date sq_ft_2600  sq_ft_800  \
# 0                NaN           NaN        NaN        NaN
# 1                NaN           NaN        NaN        NaN
# 2                NaN           NaN        NaN        NaN
# 3                NaN           NaN        NaN        NaN
# 4                NaN           NaN        NaN        NaN
# ...              ...           ...        ...        ...
# 637360           NaN           NaN       6.95       6.95
# 637361           NaN           NaN       6.95       6.95
# 637362           NaN           NaN       8.69       8.69
# 637363           NaN           NaN       8.59       8.59
# 637364           NaN           NaN       6.99       6.99
#
#                           plan_type plan_rate_min_value  plan_rate_max_value  \
# 0       Regular Residential Service                   0                  NaN
# 1       Regular Residential Service                   0                  NaN
# 2       Regular Residential Service                   0                 1200
# 3       Regular Residential Service                1201                  NaN
# 4       Regular Residential Service                   0                 1200
# ...                             ...                 ...                  ...
# 637360                          NaN                   0                  NaN
# 637361                          NaN                   0                  NaN
# 637362                          NaN                   0                  NaN
# 637363                          NaN                   0                  NaN
# 637364                          new                   0                  NaN
#
#        plan_rate_from_value plan_rate_to_value plan_rate_amount
# 0                       NaN                NaN             4.40
# 1                       NaN                NaN             4.04
# 2                       NaN                NaN             5.06
# 3                       NaN                NaN             4.23
# 4                       NaN                NaN             5.70
# ...                     ...                ...              ...
# 637360                  NaN                NaN             6.95
# 637361                  NaN                NaN             6.95
# 637362                  NaN                NaN             8.69
# 637363                  NaN                NaN             8.59
# 637364                  NaN                NaN             6.99
#
# [637365 rows x 29 columns]

# %%
# Filter amounts associated with utility rates
df_amounts_utility = df_amounts[df_amounts['rate_id'].isin(df_utility_rates['rate_id'])]

# Merge amounts with utility rates
df_utility_rates = df_utility_rates.merge(df_amounts_utility, how='left', on='rate_id')

# %%
df_utility_rates
# Out:
#      rate_id     rate_type  min_value max_value  utility_id  plan_id  \
# 0          1  default rate          0       NaN         1.0      NaN
# 1         10  default rate          0       NaN         1.0      NaN
# 2         19  default rate          0       NaN         1.0      NaN
# 3         28  default rate          0       NaN         1.0      NaN
# 4         37  default rate          0       NaN         1.0      NaN
# ..       ...           ...        ...       ...         ...      ...
# 383   637754  default rate          0       NaN         4.0      NaN
# 384   637755  default rate          0       NaN         4.0      NaN
# 385   637756  default rate          0       NaN         4.0      NaN
# 386   637757  default rate          0         -         4.0      NaN
# 387   637758  default rate          0         -         4.0      NaN
#
#       createdAt   rate_source  amount_id  from_value  to_value  value  \
# 0    1999-07-30  utility_rate          1         NaN       NaN  3.221
# 1    1999-07-30  utility_rate         16         NaN       NaN  3.221
# 2    1999-09-30  utility_rate         31         NaN       NaN  3.221
# 3    2000-03-31  utility_rate         46         NaN       NaN  3.243
# 4    2000-07-31  utility_rate         63         NaN       NaN  3.243
# ..          ...           ...        ...         ...       ...    ...
# 383  2020-09-02  utility_rate    1732253         NaN       NaN  6.369
# 384  2020-09-02  utility_rate    1732254         NaN       NaN  6.405
# 385  2020-09-03  utility_rate    1732255         NaN       NaN  6.369
# 386  2023-09-14  utility_rate    1732256         NaN       NaN  8.917
# 387  2024-03-20  utility_rate    1732257         NaN       NaN  9.425
#
#      usage_credit_id  monthly_charge_id
# 0                NaN                NaN
# 1                NaN                NaN
# 2                NaN                NaN
# 3                NaN                NaN
# 4                NaN                NaN
# ..               ...                ...
# 383              NaN                NaN
# 384              NaN                NaN
# 385              NaN                NaN
# 386              NaN                NaN
# 387              NaN                NaN
#
# [388 rows x 14 columns]

# %%
df_utility_rates.columns
# Out:
# Index(['rate_id', 'rate_type', 'min_value', 'max_value', 'utility_id',
#        'plan_id', 'createdAt', 'rate_source', 'amount_id', 'from_value',
#        'to_value', 'value', 'usage_credit_id', 'monthly_charge_id'],
#       dtype='object')

# %%
utility_rates_columns = [
    "utility_id","rate_type","createdAt","from_value","to_value","value"
]

# Select the columns
df_utility_rates_amounts = df_utility_rates[utility_rates_columns].copy()

# %%
df_utility_rates_amounts
# Out:
#      utility_id     rate_type   createdAt  from_value  to_value  value
# 0           1.0  default rate  1999-07-30         NaN       NaN  3.221
# 1           1.0  default rate  1999-07-30         NaN       NaN  3.221
# 2           1.0  default rate  1999-09-30         NaN       NaN  3.221
# 3           1.0  default rate  2000-03-31         NaN       NaN  3.243
# 4           1.0  default rate  2000-07-31         NaN       NaN  3.243
# ..          ...           ...         ...         ...       ...    ...
# 383         4.0  default rate  2020-09-02         NaN       NaN  6.369
# 384         4.0  default rate  2020-09-02         NaN       NaN  6.405
# 385         4.0  default rate  2020-09-03         NaN       NaN  6.369
# 386         4.0  default rate  2023-09-14         NaN       NaN  8.917
# 387         4.0  default rate  2024-03-20         NaN       NaN  9.425
#
# [388 rows x 6 columns]

# %%
# Rename columns to include 'plan_rate_' prefix
df_utility_rates_amounts.rename(columns={
    'createdAt': 'created_at',
    'from_value': 'utility_rate_from_value',
    'to_value': 'utility_rate_to_value',
    'value': 'utility_rate_value',
    'rate_type': 'utility_rate_type',
}, inplace=True)

# %%
df_utility_rates_amounts
# Out:
#      utility_id utility_rate_type  created_at  utility_rate_from_value  \
# 0           1.0      default rate  1999-07-30                      NaN
# 1           1.0      default rate  1999-07-30                      NaN
# 2           1.0      default rate  1999-09-30                      NaN
# 3           1.0      default rate  2000-03-31                      NaN
# 4           1.0      default rate  2000-07-31                      NaN
# ..          ...               ...         ...                      ...
# 383         4.0      default rate  2020-09-02                      NaN
# 384         4.0      default rate  2020-09-02                      NaN
# 385         4.0      default rate  2020-09-03                      NaN
# 386         4.0      default rate  2023-09-14                      NaN
# 387         4.0      default rate  2024-03-20                      NaN
#
#      utility_rate_to_value  utility_rate_value
# 0                      NaN               3.221
# 1                      NaN               3.221
# 2                      NaN               3.221
# 3                      NaN               3.243
# 4                      NaN               3.243
# ..                     ...                 ...
# 383                    NaN               6.369
# 384                    NaN               6.405
# 385                    NaN               6.369
# 386                    NaN               8.917
# 387                    NaN               9.425
#
# [388 rows x 6 columns]

# %%
# add names to utility _rates_amounts
df_utility_rates_amounts = pd.merge(df_utilities,df_utility_rates_amounts,on="utility_id")

# %%
df_utility_rates_amounts
# Out:
#      utility_id     utility_name utility_rate_type  created_at  \
# 0             1  Allegheny Power      default rate  1999-07-30
# 1             1  Allegheny Power      default rate  1999-07-30
# 2             1  Allegheny Power      default rate  1999-09-30
# 3             1  Allegheny Power      default rate  2000-03-31
# 4             1  Allegheny Power      default rate  2000-07-31
# ..          ...              ...               ...         ...
# 383           9  West Penn Power      default rate  2019-09-01
# 384           9  West Penn Power      default rate  2019-12-01
# 385           9  West Penn Power      default rate  2020-04-06
# 386           9  West Penn Power      default rate  2023-09-14
# 387           9  West Penn Power      default rate  2023-12-07
#
#      utility_rate_from_value  utility_rate_to_value  utility_rate_value
# 0                        NaN                    NaN               3.221
# 1                        NaN                    NaN               3.221
# 2                        NaN                    NaN               3.221
# 3                        NaN                    NaN               3.243
# 4                        NaN                    NaN               3.243
# ..                       ...                    ...                 ...
# 383                      NaN                    NaN               5.338
# 384                      NaN                    NaN               5.760
# 385                      NaN                    NaN               6.059
# 386                      NaN                    NaN               9.929
# 387                      NaN                    NaN               9.997
#
# [388 rows x 7 columns]

# %%
# Convert 'plan_rate_created_at' to datetime
df_utility_plan_rates_amounts['created_at'] = pd.to_datetime(df_utility_plan_rates_amounts['created_at'])

# Convert 'utility_created_at' to datetime
df_utility_rates_amounts['created_at'] = pd.to_datetime(df_utility_rates_amounts['created_at'])

# %%
# Sort df_utility_rates_amounts by 'utility_id' and 'utility_created_at'
df_utility_rates_amounts_sorted = df_utility_rates_amounts.sort_values(['utility_id', 'created_at'])

# Sort df_utility_plan_rates_amounts by 'utility_id' and 'plan_rate_created_at'
df_utility_plan_rates_amounts_sorted = df_utility_plan_rates_amounts.sort_values(['utility_id', 'created_at'])

# %%
# Convert 'utility_id' to int64 in df_utility_rates_amounts
df_utility_rates_amounts_sorted['utility_id'] = df_utility_rates_amounts_sorted['utility_id'].astype('int64')

# Convert 'utility_id' to int64 in df_utility_plan_rates_amounts
df_utility_plan_rates_amounts_sorted['utility_id'] = df_utility_plan_rates_amounts_sorted['utility_id'].astype('int64')

# %%
print("Data types in df_utility_rates_amounts:")
print(df_utility_rates_amounts_sorted[['utility_id']].dtypes)

# Check data types of 'utility_id' in df_utility_plan_rates_amounts
print("\nData types in df_utility_plan_rates_amounts:")
print(df_utility_plan_rates_amounts_sorted[['utility_id']].dtypes)
# Out:
# Data types in df_utility_rates_amounts:
# utility_id    int64
# dtype: object
#
# Data types in df_utility_plan_rates_amounts:
# utility_id    int64
# dtype: object

# %%
df_utility_rates_amounts_sorted.columns
# Out:
# Index(['utility_id', 'utility_name', 'utility_rate_type', 'created_at',
#        'utility_rate_from_value', 'utility_rate_to_value',
#        'utility_rate_value'],
#       dtype='object')

# %%
df_utility_plan_rates_amounts_sorted.columns
# Out:
# Index(['utility_id', 'utility_name', 'supplier_id', 'supplier_name', 'plan_id',
#        'created_at', 'state', 'rate_unit', 'contact_number', 'is_variable',
#        'rate_type_plan', 'is_green', 'description', 'term', 'website_url',
#        'green_details', 'green_percentage', 'start_date', 'service_type',
#        'term_end_date', 'plan_end_date', 'sq_ft_2600', 'sq_ft_800',
#        'plan_type', 'plan_rate_min_value', 'plan_rate_max_value',
#        'plan_rate_from_value', 'plan_rate_to_value', 'plan_rate_amount'],
#       dtype='object')

# %%
df_utility_rates_amounts_sorted
# Out:
#      utility_id     utility_name utility_rate_type created_at  \
# 0             1  Allegheny Power      default rate 1999-07-30
# 1             1  Allegheny Power      default rate 1999-07-30
# 2             1  Allegheny Power      default rate 1999-09-30
# 6             1  Allegheny Power      default rate 2000-02-25
# 7             1  Allegheny Power      default rate 2000-02-25
# ..          ...              ...               ...        ...
# 383           9  West Penn Power      default rate 2019-09-01
# 384           9  West Penn Power      default rate 2019-12-01
# 385           9  West Penn Power      default rate 2020-04-06
# 386           9  West Penn Power      default rate 2023-09-14
# 387           9  West Penn Power      default rate 2023-12-07
#
#      utility_rate_from_value  utility_rate_to_value  utility_rate_value
# 0                        NaN                    NaN               3.221
# 1                        NaN                    NaN               3.221
# 2                        NaN                    NaN               3.221
# 6                        NaN                    NaN               3.243
# 7                        NaN                    NaN               3.243
# ..                       ...                    ...                 ...
# 383                      NaN                    NaN               5.338
# 384                      NaN                    NaN               5.760
# 385                      NaN                    NaN               6.059
# 386                      NaN                    NaN               9.929
# 387                      NaN                    NaN               9.997
#
# [388 rows x 7 columns]

# %%
df_utility_plan_rates_amounts_sorted
# Out:
#         utility_id     utility_name  supplier_id          supplier_name  \
# 0                1  Allegheny Power            1            FirstEnergy
# 1                1  Allegheny Power            2  Green Mountain Energy
# 2                1  Allegheny Power            2  Green Mountain Energy
# 3                1  Allegheny Power            2  Green Mountain Energy
# 4                1  Allegheny Power            2  Green Mountain Energy
# ...            ...              ...          ...                    ...
# 637350           9  West Penn Power           87        Tomorrow Energy
# 637351           9  West Penn Power           67     Town Square Energy
# 637352           9  West Penn Power           67     Town Square Energy
# 637353           9  West Penn Power           67     Town Square Energy
# 637364           9  West Penn Power          111       Clean Sky Energy
#
#          plan_id created_at state rate_unit contact_number is_variable  ...  \
# 0            1.0 1999-07-30    pa       kWh   888-254-9227        True  ...
# 1            2.0 1999-07-30    pa       kWh   888-246-6730        True  ...
# 2            3.0 1999-07-30    pa       kWh   888-246-6730        True  ...
# 3            3.0 1999-07-30    pa       kWh   888-246-6730        True  ...
# 4            4.0 1999-07-30    pa       kWh   888-246-6730        True  ...
# ...          ...        ...   ...       ...            ...         ...  ...
# 637350  637678.0 2021-07-21    pa       kWh            NaN         NaN  ...
# 637351  637679.0 2021-07-21    pa       kWh            NaN         NaN  ...
# 637352  637680.0 2021-07-21    pa       kWh            NaN         NaN  ...
# 637353  637681.0 2021-07-21    pa       kWh            NaN         NaN  ...
# 637364  637692.0 2021-07-21    pa       kWh            NaN         NaN  ...
#
#        term_end_date plan_end_date sq_ft_2600  sq_ft_800  \
# 0                NaN           NaN        NaN        NaN
# 1                NaN           NaN        NaN        NaN
# 2                NaN           NaN        NaN        NaN
# 3                NaN           NaN        NaN        NaN
# 4                NaN           NaN        NaN        NaN
# ...              ...           ...        ...        ...
# 637350           NaN           NaN       7.67       7.67
# 637351           NaN           NaN       6.04       6.04
# 637352           NaN           NaN       7.97       7.97
# 637353           NaN           NaN       7.97       7.97
# 637364           NaN           NaN       6.99       6.99
#
#                           plan_type plan_rate_min_value  plan_rate_max_value  \
# 0       Regular Residential Service                   0                  NaN
# 1       Regular Residential Service                   0                  NaN
# 2       Regular Residential Service                   0                 1200
# 3       Regular Residential Service                1201                  NaN
# 4       Regular Residential Service                   0                 1200
# ...                             ...                 ...                  ...
# 637350                     existing                   0                  NaN
# 637351                          NaN                   0                  NaN
# 637352                          NaN                   0                  NaN
# 637353                          NaN                   0                  NaN
# 637364                          new                   0                  NaN
#
#        plan_rate_from_value plan_rate_to_value plan_rate_amount
# 0                       NaN                NaN             4.40
# 1                       NaN                NaN             4.04
# 2                       NaN                NaN             5.06
# 3                       NaN                NaN             4.23
# 4                       NaN                NaN             5.70
# ...                     ...                ...              ...
# 637350                  NaN                NaN             7.67
# 637351                  NaN                NaN             6.04
# 637352                  NaN                NaN             7.97
# 637353                  NaN                NaN             7.97
# 637364                  NaN                NaN             6.99
#
# [637365 rows x 29 columns]

# %%
# Check for missing 'utility_id' and date columns in df_utility_rates_amounts_sorted
missing_util_id_rates = df_utility_rates_amounts_sorted['utility_id'].isnull().sum()
missing_dates_rates = df_utility_rates_amounts_sorted['created_at'].isnull().sum()
print(f"Missing 'utility_id' in df_utility_rates_amounts_sorted: {missing_util_id_rates}")
print(f"Missing 'utility_created_at' in df_utility_rates_amounts_sorted: {missing_dates_rates}")
# Out:
# Missing 'utility_id' in df_utility_rates_amounts_sorted: 0
# Missing 'utility_created_at' in df_utility_rates_amounts_sorted: 0

# %%
# Check for missing 'utility_id' and date columns in df_utility_plan_rates_amounts_sorted
missing_util_id_plan = df_utility_plan_rates_amounts_sorted['utility_id'].isnull().sum()
missing_dates_plan = df_utility_plan_rates_amounts_sorted['created_at'].isnull().sum()
print(f"\nMissing 'utility_id' in df_utility_plan_rates_amounts_sorted: {missing_util_id_plan}")
print(f"Missing 'plan_rate_created_at' in df_utility_plan_rates_amounts_sorted: {missing_dates_plan}")
# Out:
# Missing 'utility_id' in df_utility_plan_rates_amounts_sorted: 0
# Missing 'plan_rate_created_at' in df_utility_plan_rates_amounts_sorted: 0

# %%
merged_df = pd.merge(
    df_utility_rates_amounts,
    df_utility_plan_rates_amounts,
    how='left',
    on=['utility_id', 'created_at'],
    suffixes=('_utility', '_plan')
)

# %%
merged_df
# Out:
#        utility_id utility_name_utility utility_rate_type created_at  \
# 0               1      Allegheny Power      default rate 1999-07-30
# 1               1      Allegheny Power      default rate 1999-07-30
# 2               1      Allegheny Power      default rate 1999-07-30
# 3               1      Allegheny Power      default rate 1999-07-30
# 4               1      Allegheny Power      default rate 1999-07-30
# ...           ...                  ...               ...        ...
# 19709           9      West Penn Power      default rate 2020-04-06
# 19710           9      West Penn Power      default rate 2020-04-06
# 19711           9      West Penn Power      default rate 2020-04-06
# 19712           9      West Penn Power      default rate 2023-09-14
# 19713           9      West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_value  \
# 0                          NaN                    NaN               3.221
# 1                          NaN                    NaN               3.221
# 2                          NaN                    NaN               3.221
# 3                          NaN                    NaN               3.221
# 4                          NaN                    NaN               3.221
# ...                        ...                    ...                 ...
# 19709                      NaN                    NaN               6.059
# 19710                      NaN                    NaN               6.059
# 19711                      NaN                    NaN               6.059
# 19712                      NaN                    NaN               9.929
# 19713                      NaN                    NaN               9.997
#
#       utility_name_plan  supplier_id          supplier_name  ...  \
# 0       Allegheny Power          1.0            FirstEnergy  ...
# 1       Allegheny Power          2.0  Green Mountain Energy  ...
# 2       Allegheny Power          2.0  Green Mountain Energy  ...
# 3       Allegheny Power          2.0  Green Mountain Energy  ...
# 4       Allegheny Power          2.0  Green Mountain Energy  ...
# ...                 ...          ...                    ...  ...
# 19709   West Penn Power         67.0     Town Square Energy  ...
# 19710   West Penn Power         67.0     Town Square Energy  ...
# 19711   West Penn Power         67.0     Town Square Energy  ...
# 19712               NaN          NaN                    NaN  ...
# 19713               NaN          NaN                    NaN  ...
#
#        term_end_date plan_end_date sq_ft_2600 sq_ft_800  \
# 0                NaN           NaN        NaN       NaN
# 1                NaN           NaN        NaN       NaN
# 2                NaN           NaN        NaN       NaN
# 3                NaN           NaN        NaN       NaN
# 4                NaN           NaN        NaN       NaN
# ...              ...           ...        ...       ...
# 19709            NaN           NaN        NaN       NaN
# 19710            NaN           NaN        NaN       NaN
# 19711            NaN           NaN        NaN       NaN
# 19712            NaN           NaN        NaN       NaN
# 19713            NaN           NaN        NaN       NaN
#
#                          plan_type plan_rate_min_value plan_rate_max_value  \
# 0      Regular Residential Service                 0.0                 NaN
# 1      Regular Residential Service                 0.0                 NaN
# 2      Regular Residential Service                 0.0                1200
# 3      Regular Residential Service              1201.0                 NaN
# 4      Regular Residential Service                 0.0                1200
# ...                            ...                 ...                 ...
# 19709                          NaN                 0.0                 NaN
# 19710                          NaN                 0.0                 NaN
# 19711                          NaN                 0.0                 NaN
# 19712                          NaN                 NaN                 NaN
# 19713                          NaN                 NaN                 NaN
#
#       plan_rate_from_value  plan_rate_to_value plan_rate_amount
# 0                      NaN                 NaN             4.40
# 1                      NaN                 NaN             4.04
# 2                      NaN                 NaN             5.06
# 3                      NaN                 NaN             4.23
# 4                      NaN                 NaN             5.70
# ...                    ...                 ...              ...
# 19709                  NaN                 NaN             5.28
# 19710                  NaN                 NaN             6.76
# 19711                  NaN                 NaN             6.87
# 19712                  NaN                 NaN              NaN
# 19713                  NaN                 NaN              NaN
#
# [19714 rows x 34 columns]

# %%
merged_df.columns
# Out:
# Index(['utility_id', 'utility_name_utility', 'utility_rate_type', 'created_at',
#        'utility_rate_from_value', 'utility_rate_to_value',
#        'utility_rate_value', 'utility_name_plan', 'supplier_id',
#        'supplier_name', 'plan_id', 'state', 'rate_unit', 'contact_number',
#        'is_variable', 'rate_type_plan', 'is_green', 'description', 'term',
#        'website_url', 'green_details', 'green_percentage', 'start_date',
#        'service_type', 'term_end_date', 'plan_end_date', 'sq_ft_2600',
#        'sq_ft_800', 'plan_type', 'plan_rate_min_value', 'plan_rate_max_value',
#        'plan_rate_from_value', 'plan_rate_to_value', 'plan_rate_amount'],
#       dtype='object')

# %%
required_columns = [
    'utility_id',
    'utility_name_utility',
    'utility_rate_type',
    'created_at',
    'utility_rate_from_value',
    'utility_rate_to_value',
    'utility_rate_value',
    'supplier_id',
    'supplier_name',
    'plan_id',
    'state',
    'rate_unit',
    'contact_number',
    'is_variable',
    'rate_type_plan',
    'is_green',
    'description',
    'term',
    'website_url',
    'green_details',
    'green_percentage',
    'start_date',
    'service_type',
    'term_end_date',
    'plan_end_date',
    'sq_ft_2600',
    'sq_ft_800',
    'plan_type',
    'plan_rate_min_value',
    'plan_rate_max_value',
    'plan_rate_from_value',
    'plan_rate_to_value',
    'plan_rate_amount']

# %%
merged_df = merged_df[required_columns].copy()

# %%
merged_df
# Out:
#        utility_id utility_name_utility utility_rate_type created_at  \
# 0               1      Allegheny Power      default rate 1999-07-30
# 1               1      Allegheny Power      default rate 1999-07-30
# 2               1      Allegheny Power      default rate 1999-07-30
# 3               1      Allegheny Power      default rate 1999-07-30
# 4               1      Allegheny Power      default rate 1999-07-30
# ...           ...                  ...               ...        ...
# 19709           9      West Penn Power      default rate 2020-04-06
# 19710           9      West Penn Power      default rate 2020-04-06
# 19711           9      West Penn Power      default rate 2020-04-06
# 19712           9      West Penn Power      default rate 2023-09-14
# 19713           9      West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_value  \
# 0                          NaN                    NaN               3.221
# 1                          NaN                    NaN               3.221
# 2                          NaN                    NaN               3.221
# 3                          NaN                    NaN               3.221
# 4                          NaN                    NaN               3.221
# ...                        ...                    ...                 ...
# 19709                      NaN                    NaN               6.059
# 19710                      NaN                    NaN               6.059
# 19711                      NaN                    NaN               6.059
# 19712                      NaN                    NaN               9.929
# 19713                      NaN                    NaN               9.997
#
#        supplier_id          supplier_name   plan_id  ... term_end_date  \
# 0              1.0            FirstEnergy       1.0  ...           NaN
# 1              2.0  Green Mountain Energy       2.0  ...           NaN
# 2              2.0  Green Mountain Energy       3.0  ...           NaN
# 3              2.0  Green Mountain Energy       3.0  ...           NaN
# 4              2.0  Green Mountain Energy       4.0  ...           NaN
# ...            ...                    ...       ...  ...           ...
# 19709         67.0     Town Square Energy  223771.0  ...           NaN
# 19710         67.0     Town Square Energy  223772.0  ...           NaN
# 19711         67.0     Town Square Energy  223773.0  ...           NaN
# 19712          NaN                    NaN       NaN  ...           NaN
# 19713          NaN                    NaN       NaN  ...           NaN
#
#       plan_end_date sq_ft_2600 sq_ft_800                    plan_type  \
# 0               NaN        NaN       NaN  Regular Residential Service
# 1               NaN        NaN       NaN  Regular Residential Service
# 2               NaN        NaN       NaN  Regular Residential Service
# 3               NaN        NaN       NaN  Regular Residential Service
# 4               NaN        NaN       NaN  Regular Residential Service
# ...             ...        ...       ...                          ...
# 19709           NaN        NaN       NaN                          NaN
# 19710           NaN        NaN       NaN                          NaN
# 19711           NaN        NaN       NaN                          NaN
# 19712           NaN        NaN       NaN                          NaN
# 19713           NaN        NaN       NaN                          NaN
#
#       plan_rate_min_value plan_rate_max_value  plan_rate_from_value  \
# 0                     0.0                 NaN                   NaN
# 1                     0.0                 NaN                   NaN
# 2                     0.0                1200                   NaN
# 3                  1201.0                 NaN                   NaN
# 4                     0.0                1200                   NaN
# ...                   ...                 ...                   ...
# 19709                 0.0                 NaN                   NaN
# 19710                 0.0                 NaN                   NaN
# 19711                 0.0                 NaN                   NaN
# 19712                 NaN                 NaN                   NaN
# 19713                 NaN                 NaN                   NaN
#
#       plan_rate_to_value plan_rate_amount
# 0                    NaN             4.40
# 1                    NaN             4.04
# 2                    NaN             5.06
# 3                    NaN             4.23
# 4                    NaN             5.70
# ...                  ...              ...
# 19709                NaN             5.28
# 19710                NaN             6.76
# 19711                NaN             6.87
# 19712                NaN              NaN
# 19713                NaN              NaN
#
# [19714 rows x 33 columns]

# %%
merged_df.rename(columns={
    'utility_name_utility': 'utility_name',
    'utility_rate_value': 'utility_rate_amount',
}, inplace=True)

# %%
merged_df
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 19709           9  West Penn Power      default rate 2020-04-06
# 19710           9  West Penn Power      default rate 2020-04-06
# 19711           9  West Penn Power      default rate 2020-04-06
# 19712           9  West Penn Power      default rate 2023-09-14
# 19713           9  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 19709                      NaN                    NaN                6.059
# 19710                      NaN                    NaN                6.059
# 19711                      NaN                    NaN                6.059
# 19712                      NaN                    NaN                9.929
# 19713                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ... term_end_date  \
# 0              1.0            FirstEnergy       1.0  ...           NaN
# 1              2.0  Green Mountain Energy       2.0  ...           NaN
# 2              2.0  Green Mountain Energy       3.0  ...           NaN
# 3              2.0  Green Mountain Energy       3.0  ...           NaN
# 4              2.0  Green Mountain Energy       4.0  ...           NaN
# ...            ...                    ...       ...  ...           ...
# 19709         67.0     Town Square Energy  223771.0  ...           NaN
# 19710         67.0     Town Square Energy  223772.0  ...           NaN
# 19711         67.0     Town Square Energy  223773.0  ...           NaN
# 19712          NaN                    NaN       NaN  ...           NaN
# 19713          NaN                    NaN       NaN  ...           NaN
#
#       plan_end_date sq_ft_2600 sq_ft_800                    plan_type  \
# 0               NaN        NaN       NaN  Regular Residential Service
# 1               NaN        NaN       NaN  Regular Residential Service
# 2               NaN        NaN       NaN  Regular Residential Service
# 3               NaN        NaN       NaN  Regular Residential Service
# 4               NaN        NaN       NaN  Regular Residential Service
# ...             ...        ...       ...                          ...
# 19709           NaN        NaN       NaN                          NaN
# 19710           NaN        NaN       NaN                          NaN
# 19711           NaN        NaN       NaN                          NaN
# 19712           NaN        NaN       NaN                          NaN
# 19713           NaN        NaN       NaN                          NaN
#
#       plan_rate_min_value plan_rate_max_value  plan_rate_from_value  \
# 0                     0.0                 NaN                   NaN
# 1                     0.0                 NaN                   NaN
# 2                     0.0                1200                   NaN
# 3                  1201.0                 NaN                   NaN
# 4                     0.0                1200                   NaN
# ...                   ...                 ...                   ...
# 19709                 0.0                 NaN                   NaN
# 19710                 0.0                 NaN                   NaN
# 19711                 0.0                 NaN                   NaN
# 19712                 NaN                 NaN                   NaN
# 19713                 NaN                 NaN                   NaN
#
#       plan_rate_to_value plan_rate_amount
# 0                    NaN             4.40
# 1                    NaN             4.04
# 2                    NaN             5.06
# 3                    NaN             4.23
# 4                    NaN             5.70
# ...                  ...              ...
# 19709                NaN             5.28
# 19710                NaN             6.76
# 19711                NaN             6.87
# 19712                NaN              NaN
# 19713                NaN              NaN
#
# [19714 rows x 33 columns]

# %%
dataset_with_benefits = pd.merge(merged_df, df_benefits, on="plan_id", how="left")

# %%
drop_columns = [
    "benefit_id",
    ]
dataset_with_benefits.drop(columns=drop_columns, inplace=True)

# %%
dataset_with_benefits.rename(columns={
    'value': 'benefits_value',
}, inplace=True)

# %%
dataset_with_benefits
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 19991           9  West Penn Power      default rate 2020-04-06
# 19992           9  West Penn Power      default rate 2020-04-06
# 19993           9  West Penn Power      default rate 2020-04-06
# 19994           9  West Penn Power      default rate 2023-09-14
# 19995           9  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 19991                      NaN                    NaN                6.059
# 19992                      NaN                    NaN                6.059
# 19993                      NaN                    NaN                6.059
# 19994                      NaN                    NaN                9.929
# 19995                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ... sq_ft_2600 sq_ft_800  \
# 0              1.0            FirstEnergy       1.0  ...        NaN       NaN
# 1              2.0  Green Mountain Energy       2.0  ...        NaN       NaN
# 2              2.0  Green Mountain Energy       3.0  ...        NaN       NaN
# 3              2.0  Green Mountain Energy       3.0  ...        NaN       NaN
# 4              2.0  Green Mountain Energy       4.0  ...        NaN       NaN
# ...            ...                    ...       ...  ...        ...       ...
# 19991         67.0     Town Square Energy  223771.0  ...        NaN       NaN
# 19992         67.0     Town Square Energy  223772.0  ...        NaN       NaN
# 19993         67.0     Town Square Energy  223773.0  ...        NaN       NaN
# 19994          NaN                    NaN       NaN  ...        NaN       NaN
# 19995          NaN                    NaN       NaN  ...        NaN       NaN
#
#                          plan_type plan_rate_min_value plan_rate_max_value  \
# 0      Regular Residential Service                 0.0                 NaN
# 1      Regular Residential Service                 0.0                 NaN
# 2      Regular Residential Service                 0.0                1200
# 3      Regular Residential Service              1201.0                 NaN
# 4      Regular Residential Service                 0.0                1200
# ...                            ...                 ...                 ...
# 19991                          NaN                 0.0                 NaN
# 19992                          NaN                 0.0                 NaN
# 19993                          NaN                 0.0                 NaN
# 19994                          NaN                 NaN                 NaN
# 19995                          NaN                 NaN                 NaN
#
#       plan_rate_from_value plan_rate_to_value  plan_rate_amount benefit_type  \
# 0                      NaN                NaN              4.40          NaN
# 1                      NaN                NaN              4.04          NaN
# 2                      NaN                NaN              5.06          NaN
# 3                      NaN                NaN              4.23          NaN
# 4                      NaN                NaN              5.70          NaN
# ...                    ...                ...               ...          ...
# 19991                  NaN                NaN              5.28          NaN
# 19992                  NaN                NaN              6.76          NaN
# 19993                  NaN                NaN              6.87          NaN
# 19994                  NaN                NaN               NaN          NaN
# 19995                  NaN                NaN               NaN          NaN
#
#       benefits_value
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 19991            NaN
# 19992            NaN
# 19993            NaN
# 19994            NaN
# 19995            NaN
#
# [19996 rows x 35 columns]

# %%
df_amounts
# Out:
#          amount_id  from_value  to_value  value   rate_id  usage_credit_id  \
# 0                1         NaN       NaN  3.221       1.0              NaN
# 1                2         NaN       NaN  4.400       2.0              NaN
# 2                3         NaN       NaN  0.000       NaN              1.0
# 3                4         NaN       NaN  4.040       3.0              NaN
# 4                5         NaN       NaN  0.000       NaN              2.0
# ...            ...         ...       ...    ...       ...              ...
# 1732252    1732253         NaN       NaN  6.369  637754.0              NaN
# 1732253    1732254         NaN       NaN  6.405  637755.0              NaN
# 1732254    1732255         NaN       NaN  6.369  637756.0              NaN
# 1732255    1732256         NaN       NaN  8.917  637757.0              NaN
# 1732256    1732257         NaN       NaN  9.425  637758.0              NaN
#
#          monthly_charge_id
# 0                      NaN
# 1                      NaN
# 2                      NaN
# 3                      NaN
# 4                      NaN
# ...                    ...
# 1732252                NaN
# 1732253                NaN
# 1732254                NaN
# 1732255                NaN
# 1732256                NaN
#
# [1732257 rows x 7 columns]

# %%
df_monthly_charges_amounts = pd.merge(df_monthly_charges, df_amounts, on="monthly_charge_id", how="left")
drop_columns = [
    "monthly_charge_id",
    "amount_id",
    "rate_id",
    "usage_credit_id"
]

# %%
df_monthly_charges_amounts.columns
# Out:
# Index(['monthly_charge_id', 'min_value', 'max_value', 'plan_id', 'amount_id',
#        'from_value', 'to_value', 'value', 'rate_id', 'usage_credit_id'],
#       dtype='object')

# %%
df_monthly_charges_amounts.drop(columns=drop_columns, inplace=True)

# %%
df_monthly_charges_amounts.rename(columns={
    "value": "monthly_charge_amount",
    "min_value": "monthly_charge_min_value",
    "max_value": "monthly_charge_max_value",
    "from_value": "monthly_charge_from_value",
    "to_value": "monthly_charge_to_value"
}, inplace=True)

# %%
df_monthly_charges_amounts.columns
# Out:
# Index(['monthly_charge_min_value', 'monthly_charge_max_value', 'plan_id',
#        'monthly_charge_from_value', 'monthly_charge_to_value',
#        'monthly_charge_amount'],
#       dtype='object')

# %%
dataset_with_monthly_charges = pd.merge(dataset_with_benefits, df_monthly_charges_amounts, on="plan_id", how="left")

# %%
dataset_with_monthly_charges
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 19991           9  West Penn Power      default rate 2020-04-06
# 19992           9  West Penn Power      default rate 2020-04-06
# 19993           9  West Penn Power      default rate 2020-04-06
# 19994           9  West Penn Power      default rate 2023-09-14
# 19995           9  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 19991                      NaN                    NaN                6.059
# 19992                      NaN                    NaN                6.059
# 19993                      NaN                    NaN                6.059
# 19994                      NaN                    NaN                9.929
# 19995                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ... plan_rate_from_value  \
# 0              1.0            FirstEnergy       1.0  ...                  NaN
# 1              2.0  Green Mountain Energy       2.0  ...                  NaN
# 2              2.0  Green Mountain Energy       3.0  ...                  NaN
# 3              2.0  Green Mountain Energy       3.0  ...                  NaN
# 4              2.0  Green Mountain Energy       4.0  ...                  NaN
# ...            ...                    ...       ...  ...                  ...
# 19991         67.0     Town Square Energy  223771.0  ...                  NaN
# 19992         67.0     Town Square Energy  223772.0  ...                  NaN
# 19993         67.0     Town Square Energy  223773.0  ...                  NaN
# 19994          NaN                    NaN       NaN  ...                  NaN
# 19995          NaN                    NaN       NaN  ...                  NaN
#
#       plan_rate_to_value plan_rate_amount benefit_type benefits_value  \
# 0                    NaN             4.40          NaN            NaN
# 1                    NaN             4.04          NaN            NaN
# 2                    NaN             5.06          NaN            NaN
# 3                    NaN             4.23          NaN            NaN
# 4                    NaN             5.70          NaN            NaN
# ...                  ...              ...          ...            ...
# 19991                NaN             5.28          NaN            NaN
# 19992                NaN             6.76          NaN            NaN
# 19993                NaN             6.87          NaN            NaN
# 19994                NaN              NaN          NaN            NaN
# 19995                NaN              NaN          NaN            NaN
#
#       monthly_charge_min_value monthly_charge_max_value  \
# 0                          NaN                      NaN
# 1                          NaN                      NaN
# 2                          NaN                      NaN
# 3                          NaN                      NaN
# 4                          NaN                      NaN
# ...                        ...                      ...
# 19991                      0.0                      NaN
# 19992                      0.0                      NaN
# 19993                      0.0                      NaN
# 19994                      NaN                      NaN
# 19995                      NaN                      NaN
#
#        monthly_charge_from_value monthly_charge_to_value monthly_charge_amount
# 0                            NaN                     NaN                   NaN
# 1                            NaN                     NaN                   NaN
# 2                            NaN                     NaN                   NaN
# 3                            NaN                     NaN                   NaN
# 4                            NaN                     NaN                   NaN
# ...                          ...                     ...                   ...
# 19991                        NaN                     NaN                   0.0
# 19992                        NaN                     NaN                   0.0
# 19993                        NaN                     NaN                   0.0
# 19994                        NaN                     NaN                   NaN
# 19995                        NaN                     NaN                   NaN
#
# [19996 rows x 40 columns]

# %%
drop_columns = [
    "usage_credit_id",
]
df_usage_credits.drop(columns=drop_columns, inplace=True)

# %%
df_usage_credits.rename(columns=({
    "min_value": "usage_credit_min_value",
    "max_value": "usage_credit_max_value",
}), inplace=True)

# %%
dataset_with_usage_credits = pd.merge(dataset_with_monthly_charges, df_usage_credits, on="plan_id", how="left")

# %%
dataset_with_usage_credits
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 19991           9  West Penn Power      default rate 2020-04-06
# 19992           9  West Penn Power      default rate 2020-04-06
# 19993           9  West Penn Power      default rate 2020-04-06
# 19994           9  West Penn Power      default rate 2023-09-14
# 19995           9  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 19991                      NaN                    NaN                6.059
# 19992                      NaN                    NaN                6.059
# 19993                      NaN                    NaN                6.059
# 19994                      NaN                    NaN                9.929
# 19995                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ... plan_rate_amount  \
# 0              1.0            FirstEnergy       1.0  ...             4.40
# 1              2.0  Green Mountain Energy       2.0  ...             4.04
# 2              2.0  Green Mountain Energy       3.0  ...             5.06
# 3              2.0  Green Mountain Energy       3.0  ...             4.23
# 4              2.0  Green Mountain Energy       4.0  ...             5.70
# ...            ...                    ...       ...  ...              ...
# 19991         67.0     Town Square Energy  223771.0  ...             5.28
# 19992         67.0     Town Square Energy  223772.0  ...             6.76
# 19993         67.0     Town Square Energy  223773.0  ...             6.87
# 19994          NaN                    NaN       NaN  ...              NaN
# 19995          NaN                    NaN       NaN  ...              NaN
#
#       benefit_type benefits_value monthly_charge_min_value  \
# 0              NaN            NaN                      NaN
# 1              NaN            NaN                      NaN
# 2              NaN            NaN                      NaN
# 3              NaN            NaN                      NaN
# 4              NaN            NaN                      NaN
# ...            ...            ...                      ...
# 19991          NaN            NaN                      0.0
# 19992          NaN            NaN                      0.0
# 19993          NaN            NaN                      0.0
# 19994          NaN            NaN                      NaN
# 19995          NaN            NaN                      NaN
#
#       monthly_charge_max_value monthly_charge_from_value  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 19991                      NaN                       NaN
# 19992                      NaN                       NaN
# 19993                      NaN                       NaN
# 19994                      NaN                       NaN
# 19995                      NaN                       NaN
#
#       monthly_charge_to_value  monthly_charge_amount usage_credit_min_value  \
# 0                         NaN                    NaN                    0.0
# 1                         NaN                    NaN                    0.0
# 2                         NaN                    NaN                    0.0
# 3                         NaN                    NaN                    0.0
# 4                         NaN                    NaN                    0.0
# ...                       ...                    ...                    ...
# 19991                     NaN                    0.0                    0.0
# 19992                     NaN                    0.0                    0.0
# 19993                     NaN                    0.0                    0.0
# 19994                     NaN                    NaN                    NaN
# 19995                     NaN                    NaN                    NaN
#
#       usage_credit_max_value
# 0                        NaN
# 1                        NaN
# 2                        NaN
# 3                        NaN
# 4                        NaN
# ...                      ...
# 19991                    NaN
# 19992                    NaN
# 19993                    NaN
# 19994                    NaN
# 19995                    NaN
#
# [19996 rows x 42 columns]

# %%
df_early_term_fees
# Out:
#         early_term_fee_id  min_value  max_value  fee_type  term  plan_id
# 0                       1        0.0        NaN       NaN   NaN      279
# 1                       2        0.0        NaN       NaN   NaN      281
# 2                       3        0.0        NaN       NaN   NaN      285
# 3                       4        0.0        NaN       NaN   NaN      288
# 4                       5        0.0        NaN       NaN   NaN      290
# ...                   ...        ...        ...       ...   ...      ...
# 523057             523058        0.0        NaN  straight   NaN   637688
# 523058             523059        0.0        NaN  straight   NaN   637689
# 523059             523060        0.0        NaN  straight   NaN   637690
# 523060             523061    12500.0        NaN  straight   NaN   637691
# 523061             523062        0.0        NaN  straight   NaN   637692
#
# [523062 rows x 6 columns]

# %%
drop_columns = [
    "early_term_fee_id",
]
df_early_term_fees.drop(columns=drop_columns, inplace=True)

df_early_term_fees.rename(columns=({
    "min_value": "early_term_fees_min_value",
    "max_value": "early_term_fees_max_value",
    "fee_type": "early_term_fee_type",
    "term": "early_term_fee_term"
}), inplace=True)

# %%
dataset_with_early_term_fees = pd.merge(dataset_with_usage_credits, df_early_term_fees, on="plan_id", how="left")

# %%
dataset_with_early_term_fees
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 19991           9  West Penn Power      default rate 2020-04-06
# 19992           9  West Penn Power      default rate 2020-04-06
# 19993           9  West Penn Power      default rate 2020-04-06
# 19994           9  West Penn Power      default rate 2023-09-14
# 19995           9  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 19991                      NaN                    NaN                6.059
# 19992                      NaN                    NaN                6.059
# 19993                      NaN                    NaN                6.059
# 19994                      NaN                    NaN                9.929
# 19995                      NaN                    NaN                9.997
#
#        supplier_id          supplier_name   plan_id  ...  \
# 0              1.0            FirstEnergy       1.0  ...
# 1              2.0  Green Mountain Energy       2.0  ...
# 2              2.0  Green Mountain Energy       3.0  ...
# 3              2.0  Green Mountain Energy       3.0  ...
# 4              2.0  Green Mountain Energy       4.0  ...
# ...            ...                    ...       ...  ...
# 19991         67.0     Town Square Energy  223771.0  ...
# 19992         67.0     Town Square Energy  223772.0  ...
# 19993         67.0     Town Square Energy  223773.0  ...
# 19994          NaN                    NaN       NaN  ...
# 19995          NaN                    NaN       NaN  ...
#
#       monthly_charge_max_value monthly_charge_from_value  \
# 0                          NaN                       NaN
# 1                          NaN                       NaN
# 2                          NaN                       NaN
# 3                          NaN                       NaN
# 4                          NaN                       NaN
# ...                        ...                       ...
# 19991                      NaN                       NaN
# 19992                      NaN                       NaN
# 19993                      NaN                       NaN
# 19994                      NaN                       NaN
# 19995                      NaN                       NaN
#
#       monthly_charge_to_value monthly_charge_amount usage_credit_min_value  \
# 0                         NaN                   NaN                    0.0
# 1                         NaN                   NaN                    0.0
# 2                         NaN                   NaN                    0.0
# 3                         NaN                   NaN                    0.0
# 4                         NaN                   NaN                    0.0
# ...                       ...                   ...                    ...
# 19991                     NaN                   0.0                    0.0
# 19992                     NaN                   0.0                    0.0
# 19993                     NaN                   0.0                    0.0
# 19994                     NaN                   NaN                    NaN
# 19995                     NaN                   NaN                    NaN
#
#       usage_credit_max_value early_term_fees_min_value  \
# 0                        NaN                       NaN
# 1                        NaN                       NaN
# 2                        NaN                       NaN
# 3                        NaN                       NaN
# 4                        NaN                       NaN
# ...                      ...                       ...
# 19991                    NaN                       NaN
# 19992                    NaN                       NaN
# 19993                    NaN                    5000.0
# 19994                    NaN                       NaN
# 19995                    NaN                       NaN
#
#        early_term_fees_max_value early_term_fee_type early_term_fee_term
# 0                            NaN                 NaN                 NaN
# 1                            NaN                 NaN                 NaN
# 2                            NaN                 NaN                 NaN
# 3                            NaN                 NaN                 NaN
# 4                            NaN                 NaN                 NaN
# ...                          ...                 ...                 ...
# 19991                        NaN                 NaN                 NaN
# 19992                        NaN                 NaN                 NaN
# 19993                        NaN            straight                 NaN
# 19994                        NaN                 NaN                 NaN
# 19995                        NaN                 NaN                 NaN
#
# [19996 rows x 46 columns]

# %%
dataset_with_early_term_fees.drop(columns=["plan_id","supplier_id"], inplace=True)

# %%
dataset_with_early_term_fees
# Out:
#        utility_id     utility_name utility_rate_type created_at  \
# 0               1  Allegheny Power      default rate 1999-07-30
# 1               1  Allegheny Power      default rate 1999-07-30
# 2               1  Allegheny Power      default rate 1999-07-30
# 3               1  Allegheny Power      default rate 1999-07-30
# 4               1  Allegheny Power      default rate 1999-07-30
# ...           ...              ...               ...        ...
# 19991           9  West Penn Power      default rate 2020-04-06
# 19992           9  West Penn Power      default rate 2020-04-06
# 19993           9  West Penn Power      default rate 2020-04-06
# 19994           9  West Penn Power      default rate 2023-09-14
# 19995           9  West Penn Power      default rate 2023-12-07
#
#        utility_rate_from_value  utility_rate_to_value  utility_rate_amount  \
# 0                          NaN                    NaN                3.221
# 1                          NaN                    NaN                3.221
# 2                          NaN                    NaN                3.221
# 3                          NaN                    NaN                3.221
# 4                          NaN                    NaN                3.221
# ...                        ...                    ...                  ...
# 19991                      NaN                    NaN                6.059
# 19992                      NaN                    NaN                6.059
# 19993                      NaN                    NaN                6.059
# 19994                      NaN                    NaN                9.929
# 19995                      NaN                    NaN                9.997
#
#                supplier_name state rate_unit  ... monthly_charge_max_value  \
# 0                FirstEnergy    pa       kWh  ...                      NaN
# 1      Green Mountain Energy    pa       kWh  ...                      NaN
# 2      Green Mountain Energy    pa       kWh  ...                      NaN
# 3      Green Mountain Energy    pa       kWh  ...                      NaN
# 4      Green Mountain Energy    pa       kWh  ...                      NaN
# ...                      ...   ...       ...  ...                      ...
# 19991     Town Square Energy    pa       kWh  ...                      NaN
# 19992     Town Square Energy    pa       kWh  ...                      NaN
# 19993     Town Square Energy    pa       kWh  ...                      NaN
# 19994                    NaN   NaN       NaN  ...                      NaN
# 19995                    NaN   NaN       NaN  ...                      NaN
#
#       monthly_charge_from_value monthly_charge_to_value monthly_charge_amount  \
# 0                           NaN                     NaN                   NaN
# 1                           NaN                     NaN                   NaN
# 2                           NaN                     NaN                   NaN
# 3                           NaN                     NaN                   NaN
# 4                           NaN                     NaN                   NaN
# ...                         ...                     ...                   ...
# 19991                       NaN                     NaN                   0.0
# 19992                       NaN                     NaN                   0.0
# 19993                       NaN                     NaN                   0.0
# 19994                       NaN                     NaN                   NaN
# 19995                       NaN                     NaN                   NaN
#
#       usage_credit_min_value  usage_credit_max_value  \
# 0                        0.0                     NaN
# 1                        0.0                     NaN
# 2                        0.0                     NaN
# 3                        0.0                     NaN
# 4                        0.0                     NaN
# ...                      ...                     ...
# 19991                    0.0                     NaN
# 19992                    0.0                     NaN
# 19993                    0.0                     NaN
# 19994                    NaN                     NaN
# 19995                    NaN                     NaN
#
#       early_term_fees_min_value early_term_fees_max_value  \
# 0                           NaN                       NaN
# 1                           NaN                       NaN
# 2                           NaN                       NaN
# 3                           NaN                       NaN
# 4                           NaN                       NaN
# ...                         ...                       ...
# 19991                       NaN                       NaN
# 19992                       NaN                       NaN
# 19993                    5000.0                       NaN
# 19994                       NaN                       NaN
# 19995                       NaN                       NaN
#
#        early_term_fee_type early_term_fee_term
# 0                      NaN                 NaN
# 1                      NaN                 NaN
# 2                      NaN                 NaN
# 3                      NaN                 NaN
# 4                      NaN                 NaN
# ...                    ...                 ...
# 19991                  NaN                 NaN
# 19992                  NaN                 NaN
# 19993             straight                 NaN
# 19994                  NaN                 NaN
# 19995                  NaN                 NaN
#
# [19996 rows x 44 columns]

# %%
try:
  pickle_file_path = 'WattBuyData1999_2024.pkl'
  dataset_with_early_term_fees.to_pickle(pickle_file_path)
  print(f"DataFrame successfully saved as '{pickle_file_path}'.")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# DataFrame successfully saved as 'WattBuyData1999_2024.pkl'.
